# %% [markdown]
# Build a graph from TO using D3

# %%
# import libraries (including our short d3_lib script)
from IPython.core.display import HTML
import d3_lib, random
import re

# %% [markdown]
# ### get all the TO classes and the sublcassOf relations

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# #CONSTRUCT
# #{
# #    ?x rdfs:subClassOf ?o .
# #}
# SELECT ?x ?xlabel ?o ?olabel
# WHERE
# {
#     ?x rdfs:subClassOf ?o .
#     filter(!isblank(?o))
#     filter(!regex(str(?o), "PATO"))
#     filter(regex(str(?o), "TO"))
#     ?x rdfs:label ?xlabel .
#     ?o rdfs:label ?olabel .
# }' > to.json

# %% [markdown]
# ### get for each TO class its level in the hierarchy
#
# will be used to customise the graph

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# select ?super (count(?mid) as ?distance) {
#   ?super rdfs:subClassOf* ?mid .
#   ?mid rdfs:subClassOf+ <http://purl.obolibrary.org/obo/TO_0000387> .
# }
# group by ?super ?sub
# order by ?super ?sub' > level.json

# %% [markdown]
# ### get for each TO class its type

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# select ?sub ?mid {
#   ?sub rdfs:subClassOf* ?mid .
#   ?mid rdfs:subClassOf <http://purl.obolibrary.org/obo/TO_0000387> .
# }
# group by ?mid ?sub
# ' > type.json

# %% [markdown]
# ### create the JSON file used by d3js

# %%
import json

with open('to.json') as data_file:    
    data = json.load(data_file)
    
with open('level.json') as level_file:    
    level = json.load(level_file)
    
with open('type.json') as type_file:    
    type = json.load(type_file) 
    
    list = data["results"]["bindings"]
    
    graph = {"nodes": [], "links": []}
    
    for entry in list:
        x = 1
        o = 1
        #check if the nodes already exist in the graph
        for e in graph["nodes"]:
            if e["name"] == entry["xlabel"]["value"]:
                x=graph["nodes"].index(e)
            if e["name"] == entry["olabel"]["value"]:
                o=graph["nodes"].index(e)
        # if the term does not exist, create it        
        if x==1:
            for l in level["results"]["bindings"]:
                if l["super"]["value"] == entry["x"]["value"]:
                    for t in type["results"]["bindings"]:
                        if t["sub"]["value"] == entry["x"]["value"]:
                            graph["nodes"].append( {"name": entry["xlabel"]["value"], "group": re.findall('\d+', t["mid"]["value"] ), "value": 1/int(l["distance"]["value"])} )
                            x=len(graph["nodes"])-1
        if o==1:
            for l in level["results"]["bindings"]:
                if l["super"]["value"] == entry["o"]["value"]:
                    for t in type["results"]["bindings"]:
                        if t["sub"]["value"] == entry["o"]["value"]:
                            graph["nodes"].append( {"name": entry["olabel"]["value"], "group": re.findall('\d+', t["mid"]["value"] ), "value": 1/int(l["distance"]["value"])} )
                            o=len(graph["nodes"])-1
 
        # create the link
        if  entry["x"]["value"] != entry["o"]["value"]:
            graph["links"].append( {"source": x, "target": o, "value": 10} )
        
#data["results"]['bindings'][0]['x']['value']

# %%
# visualize as force-directed graph in D3
HTML(d3_lib.set_styles(['force_directed_graph']) + 
'<script src="lib/d3/d3.min.js"></script>' + 
      d3_lib.draw_graph('force_directed_graph', {'data': graph}) )
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
#
#
# /*.node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }*/
#
# .link {
#   stroke: #777;
#   stroke-opacity: 0.3;
#   stroke-width: 1.5px;
# }
#
# .node circle {
#   fill: #ccc;
#   stroke: #000;
#   stroke-width: 1.5px;
# }
#
# .node text {
#   display: none;
#   font: 10px sans-serif;
# }
#
# .node:hover circle {
#   fill: #000;
# }
#
# .node:hover text {
#   display: inline;
# }
#
# .cell {
#   fill: none;
#   pointer-events: all;
# }
# </style><script src="lib/d3/d3.min.js"></script>
#
#                 <div id='maindiv3786686681'></div>
#
#                 <script>
#
# // Based on http://bl.ocks.org/mbostock/4062045
#
# var width = 960,
#     height = 500;
#
# var color = d3.scale.category20();
#
# var force = d3.layout.force()
#     .charge(-300)
#     .linkDistance(50)
#     .size([width, height]);
#
# d3.select("#maindiv3786686681").selectAll("svg").remove();
# // var svg = d3.select("#maindiv3786686681").append("svg")
# //     .attr("width", width)
# //     .attr("height", height)
# //     ;
#
#
#
# var svg = d3.select("#maindiv3786686681")
#   .append("svg")
#   .attr("width", 960)
#   .attr("height", 500)
#   .call(d3.behavior.zoom().on("zoom", function () {
#     svg.attr("transform", "translate(" + d3.event.translate + ")" + " scale(" + d3.event.scale + ")")
#   }))
#   .append("g");
#
#
# var graph = {'nodes': [{'name': 'phosphorus concentration', 'group': ['0000277'], 'value': 0.25}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'seed phosphorus content', 'group': ['0000277'], 'value': 0.25}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'relative phosphorus concentration', 'group': ['0000277'], 'value': 0.08333333333333333}, {'name': 'relative phosphorus concentration', 'group': ['0000164'], 'value': 0.08333333333333333}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'relative phosphorus distribution between shoot and root', 'group': ['0000277'], 'value': 0.08333333333333333}, {'name': 'relative phosphorus distribution between shoot and root', 'group': ['0000164'], 'value': 0.08333333333333333}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'shoot phosphorus content', 'group': ['0000277'], 'value': 0.25}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'leaf phosphorus content', 'group': ['0000277'], 'value': 0.25}, {'name': 'phosphorus content', 'group': ['0000277'], 'value': 0.3333333333333333}, {'name': 'floral organ identity', 'group': ['0000357'], 'value': 0.16666666666666666}, {'name': 'organ identity', 'group': ['0000357'], 'value': 0.2}, {'name': 'panicle density', 'group': ['0000017'], 'value': 0.1}, {'name': 'inflorescence density', 'group': ['0000017'], 'value': 0.125}, {'name': 'androecium morphology trait', 'group': ['0000017'], 'value': 0.16666666666666666}, {'name': 'collective phyllome structure morphology trait', 'group': ['0000017'], 'value': 0.2}, {'name': 'perianth morphology trait', 'group': ['0000017'], 'value': 0.16666666666666666}, {'name': 'corolla morphology trait', 'group': ['0000017'], 'value': 0.16666666666666666}, {'name': 'involucre morphology trait', 'group': ['0000017'], 'value': 0.16666666666666666}, {'name': 'leaf dry weight', 'group': ['0000017'], 'value': 0.125}, {'name': 'leaf weight', 'group': ['0000017'], 'value': 0.14285714285714285}, {'name': 'leaf wet weight', 'group': ['0000017'], 'value': 0.125}, {'name': 'secondary branching of inflorescence', 'group': ['0000017'], 'value': 0.07692307692307693}, {'name': 'secondary branching of inflorescence', 'group': ['0000357'], 'value': 0.07692307692307693}, {'name': 'inflorescence branching', 'group': ['0000357'], 'value': 0.08333333333333333}, {'name': 'inflorescence branching', 'group': ['0000017'], 'value': 0.08333333333333333}, {'name': 'tertiary branching of inflorescence', 'group': ['0000357'], 'value': 0.07692307692307693}, {'name': 'tertiary branching of inflorescence', 'group': ['0000017'], 'value': 0.07692307692307693}, {'name': 'inflorescence branch arrangement', 'group': ['0000357'], 'value': 0.07692307692307693}, {'name': 'inflorescence branch arrangement', 'group': ['0000017'], 'value': 0.07692307692307693}, {'name': 'primary branching of inflorescence', 'group': ['0000357'], 'value': 0.07692307692307693}, {'name': 'primary branching of inflorescence', 'group': ['0000017'], 'value': 0.07692307692307693}, {'name': 'spike exsertion', 'group': ['0000017'], 'value': 0.1111111111111111}, {'name': 'inflorescence exsertion', 'group': ['0000017'], 'value': 0.125}, {'name': 'genetically engineered male sterility', 'group': ['0000392'], 'value': 0.2}, {'name': 'male sterility type', 'group': ['0000392'], 'value': 0.25}, {'name': 'nuclear mediated male sterility', 'group': ['0000392'], 'value': 0.2}, {'name': 'genic male sterility', 'group': ['0000392'], 'value': 0.2}, {'name': 'cytoplasmic male sterility', 'group': ['0000392'], 'value': 0.2}, {'name': 'hexose content', 'group': ['0000277'], 'value': 0.2}, {'name': 'monosaccharide content', 'group': ['0000277'], 'value': 0.25}, {'name': 'beta-cryptoxanthin content', 'group': ['0000017'], 'value': 0.07142857142857142}, {'name': 'beta-cryptoxanthin co ...

# %% [markdown]
# ### Extras
# #### Save the graph

# %%
with open('data.json', 'w') as outfile:
    json.dump(graph, outfile)

# %%
graph
# Out:
# {'links': [{'source': 0, 'target': 1, 'value': 1.09},
#   {'source': 2, 'target': 1, 'value': 1.09},
#   {'source': 3, 'target': 1, 'value': 1.09},
#   {'source': 4, 'target': 1, 'value': 1.09},
#   {'source': 5, 'target': 1, 'value': 1.09},
#   {'source': 6, 'target': 1, 'value': 1.09},
#   {'source': 7, 'target': 8, 'value': 1.09},
#   {'source': 9, 'target': 10, 'value': 1.09},
#   {'source': 11, 'target': 12, 'value': 1.09},
#   {'source': 13, 'target': 12, 'value': 1.09},
#   {'source': 14, 'target': 12, 'value': 1.09},
#   {'source': 15, 'target': 12, 'value': 1.09},
#   {'source': 16, 'target': 17, 'value': 1.09},
#   {'source': 18, 'target': 17, 'value': 1.09},
#   {'source': 19, 'target': 20, 'value': 1.09},
#   {'source': 21, 'target': 20, 'value': 1.09},
#   {'source': 22, 'target': 20, 'value': 1.09},
#   {'source': 23, 'target': 20, 'value': 1.09},
#   {'source': 24, 'target': 25, 'value': 1.09},
#   {'source': 26, 'target': 27, 'value': 1.09},
#   {'source': 28, 'target': 27, 'value': 1.09},
#   {'source': 29, 'target': 27, 'value': 1.09},
#   {'source': 30, 'target': 27, 'value': 1.09},
#   {'source': 31, 'target': 32, 'value': 1.09},
#   {'source': 33, 'target': 34, 'value': 1.09},
#   {'source': 35, 'target': 34, 'value': 1.09},
#   {'source': 36, 'target': 34, 'value': 1.09},
#   {'source': 37, 'target': 34, 'value': 1.09},
#   {'source': 38, 'target': 34, 'value': 1.09},
#   {'source': 39, 'target': 40, 'value': 1.09},
#   {'source': 41, 'target': 42, 'value': 1.09},
#   {'source': 43, 'target': 42, 'value': 1.09},
#   {'source': 44, 'target': 42, 'value': 1.09},
#   {'source': 45, 'target': 46, 'value': 1.09},
#   {'source': 47, 'target': 46, 'value': 1.09},
#   {'source': 48, 'target': 46, 'value': 1.09},
#   {'source': 49, 'target': 46, 'value': 1.09},
#   {'source': 50, 'target': 46, 'value': 1.09},
#   {'source': 51, 'target': 46, 'value': 1.09},
#   {'source': 52, 'target': 46, 'value': 1.09},
#   {'source': 53, 'target': 46, 'value': 1.09},
#   {'source': 54, 'target': 46, 'value': 1.09},
#   {'source': 55, 'target': 56, 'value': 1.09},
#   {'source': 57, 'target': 56, 'value': 1.09},
#   {'source': 58, 'target': 59, 'value': 1.09},
#   {'source': 60, 'target': 59, 'value': 1.09},
#   {'source': 61, 'target': 59, 'value': 1.09},
#   {'source': 62, 'target': 63, 'value': 1.09},
#   {'source': 64, 'target': 63, 'value': 1.09},
#   {'source': 65, 'target': 63, 'value': 1.09},
#   {'source': 66, 'target': 63, 'value': 1.09},
#   {'source': 67, 'target': 63, 'value': 1.09},
#   {'source': 68, 'target': 69, 'value': 1.09},
#   {'source': 70, 'target': 69, 'value': 1.09},
#   {'source': 71, 'target': 72, 'value': 1.09},
#   {'source': 73, 'target': 72, 'value': 1.09},
#   {'source': 74, 'target': 72, 'value': 1.09},
#   {'source': 75, 'target': 72, 'value': 1.09},
#   {'source': 76, 'target': 72, 'value': 1.09},
#   {'source': 77, 'target': 72, 'value': 1.09},
#   {'source': 78, 'target': 79, 'value': 1.09},
#   {'source': 80, 'target': 79, 'value': 1.09},
#   {'source': 81, 'target': 79, 'value': 1.09},
#   {'source': 82, 'target': 83, 'value': 1.09},
#   {'source': 84, 'target': 83, 'value': 1.09},
#   {'source': 85, 'target': 83, 'value': 1.09},
#   {'source': 86, 'target': 87, 'value': 1.09},
#   {'source': 88, 'target': 87, 'value': 1.09},
#   {'source': 89, 'target': 87, 'value': 1.09},
#   {'source': 90, 'target': 87, 'value': 1.09},
#   {'source': 91, 'target': 82, 'value': 1.09},
#   {'source': 92, 'target': 82, 'value': 1.09},
#   {'source': 93, 'target': 94, 'value': 1.09},
#   {'source': 95, 'target': 94, 'value': 1.09},
#   {'source': 96, 'target': 97, 'value': 1.09},
#   {'source': 98, 'target': 97, 'value': 1.09},
#   {'source': 99, 'target': 100, 'value': 1.09},
#   {'source': 101, 'target': 100, 'value': 1.09},
#   {'source': 102, 'target': 103, 'value': 1.09},
#   {'source': 104, 'target': 103, 'value': 1.09},
#   {'source': 105, 'target': 106, 'value': 1.09},
#   {'source': 107, 'target': 108, 'value': 1.09},
#   {'source': 109, 'target': 108, 'value': 1.09},
#   {'source': 110, 'target': 111, 'value': 1.09},
#   {'source': 112, 'target': 111, 'value': 1.09},
#   {'source': 113, 'target': 114, 'value': 1.09},
#   {'source': 115, 'target': 114, 'value': 1.09},
#   {'source': 116, 'target': 114, 'value': 1.09},
#   {'source': 117, 'target': 114, 'value': 1.09},
#   {'source': 118, 'target': 114, 'value': 1.09},
#   {'source': 119, 'target': 114, 'value': 1.09},
#   {'source': 120, 'target': 121, 'value': 1.09},
#   {'source': 122, 'target': 121, 'value': 1.09},
#   {'source': 123, 'target': 121, 'value': 1.09},
#   {'source': 124, 'target': 121, 'value': 1.09},
#   {'source': 125, 'target': 121, 'value': 1.09},
#   {'source': 126, 'target': 121, 'value': 1.09},
#   {'source': 127, 'target': 121, 'value': 1.09},
#   {'source': 128, 'target': 121, 'value': 1.09},
#   {'source': 129, 'target': 121, 'value': 1.09},
#   {'source': 130, 'target': 121, 'value': 1.09},
#   {'source': 131, 'target': 121, 'value': 1.09},
#   {'source': 132, 'target': 121, 'value': 1.09},
#   {'source': 133, 'target': 121, 'value': 1.09},
#   {'source': 134, 'target': 121, 'value': 1.09},
#   {'source': 135, 'target': 121, 'value': 1.09},
#   {'source': 136, 'target': 121, 'value': 1.09},
#   {'source': 137, 'target': 138, 'value': 1.09},
#   {'source': 139, 'target': 138, 'value': 1.09},
#   {'source': 140, 'target': 138, 'value': 1.09},
#   {'source': 141, 'target': 71, 'value': 1.09},
#   {'source': 142, 'target': 71, 'value': 1.09},
#   {'source': 143, 'target': 144, 'value': 1.09},
#   {'source': 145, 'target': 146, 'value': 1.09},
#   {'source': 147, 'target': 146, 'value': 1.09},
#   {'source': 148, 'target': 146, 'value': 1.09},
#   {'source': 149, 'target': 150, 'value': 1.09},
#   {'source': 151, 'target': 150, 'value': 1.09},
#   {'source': 152, 'target': 153, 'value': 1.09},
#   {'source': 154, 'target': 155, 'value': 1.09},
#   {'source': 156, 'target': 155, 'value': 1.09},
#   {'source': 157, 'target': 155, 'value': 1.09},
#   {'source': 158, 'target': 159, 'value': 1.09},
#   {'source': 160, 'target': 159, 'value': 1.09},
#   {'source': 161, 'target': 159, 'value': 1.09},
#   {'source': 162, 'target': 159, 'value': 1.09},
#   {'source': 163, 'target': 164, 'value': 1.09},
#   {'source': 165, 'target': 166, 'value': 1.09},
#   {'source': 167, 'target': 168, 'value': 1.09},
#   {'source': 169, 'target': 168, 'value': 1.09},
#   {'source': 170, 'target': 171, 'value': 1.09},
#   {'source': 172, 'target': 171, 'value': 1.09},
#   {'source': 173, 'target': 171, 'value': 1.09},
#   {'source': 174, 'target': 175, 'value': 1.09},
#   {'source': 176, 'target': 175, 'value': 1.09},
#   {'source': 177, 'target': 175, 'value': 1.09},
#   {'source': 178, 'target': 175, 'value': 1.09},
#   {'source': 179, 'target': 180, 'value': 1.09},
#   {'source': 181, 'target': 180, 'value': 1.09},
#   {'source': 182, 'target': 180, 'value': 1.09},
#   {'source': 183, 'target': 180, 'value': 1.09},
#   {'source': 184, 'target': 180, 'value': 1.09},
#   {'source': 185, 'target': 180, 'value': 1.09},
#   {'source': 186, 'target': 180, 'value': 1.09},
#   {'source': 100, 'target': 187, 'value': 1.09},
#   {'source': 121, 'target': 187, 'value': 1.09},
#   {'source': 188, 'target': 187, 'value': 1.09},
#   {'source': 189, 'target': 187, 'value': 1.09},
#   {'source': 85, 'target': 187, 'value': 1.09},
#   {'source': 190, 'target': 187, 'value': 1.09},
#   {'source': 191, 'target': 187, 'value': 1.09},
#   {'source': 192, 'target': 187, 'value': 1.09},
#   {'source': 193, 'target': 187, 'value': 1.09},
#   {'source': 194, 'target': 187, 'value': 1.09},
#   {'source': 195, 'target': 187, 'value': 1.09},
#   {'source': 196, 'target': 197, 'value': 1.09},
#   {'source': 198, 'target': 199, 'value': 1.09},
#   {'source': 200, 'target': 201, 'value': 1.09},
#   {'source': 202, 'target': 201, 'value': 1.09},
#   {'source': 203, 'target': 201, 'value': 1.09},
#   {'source': 204, 'target': 201, 'value': 1.09},
#   {'source': 205, 'target': 201, 'value': 1.09},
#   {'source': 206, 'target': 123, 'value': 1.09},
#   {'source': 207, 'target': 123, 'value': 1.09},
#   {'source': 208, 'target': 123, 'value': 1.09},
#   {'source': 40, 'target': 209, 'value': 1.09},
#   {'source': 210, 'target': 211, 'value': 1.09},
#   {'source': 212, 'target': 211, 'value': 1.09},
#   {'source': 213, 'target': 211, 'value': 1.09},
#   {'source': 214, 'target': 211, 'value': 1.09},
#   {'source': 215, 'target': 211, 'value': 1.09},
#   {'source': 216, 'target': 217, 'value': 1.09},
#   {'source': 218, 'target': 217, 'value': 1.09},
#   {'source': 219, 'target': 217, 'value': 1.09},
#   {'source': 220, 'target': 217, 'value': 1.09},
#   {'source': 221, 'target': 217, 'value': 1.09},
#   {'source': 222, 'target': 217, 'value': 1.09},
#   {'source': 223, 'target': 224, 'value': 1.09},
#   {'source': 225, 'target': 226, 'value': 1.09},
#   {'source': 227, 'target': 228, 'value': 1.09},
#   {'source': 229, 'target': 230, 'value': 1.09},
#   {'source': 231, 'target': 230, 'value': 1.09},
#   {'source': 232, 'target': 113, 'value': 1.09},
#   {'source': 233, 'target': 113, 'value': 1.09},
#   {'source': 234, 'target': 113, 'value': 1.09},
#   {'source': 235, 'target': 113, 'value': 1.09},
#   {'source': 236, 'target': 113, 'value': 1.09},
#   {'source': 237, 'target': 113, 'value': 1.09},
#   {'source': 238, 'target': 239, 'value': 1.09},
#   {'source': 240, 'target': 239, 'value': 1.09},
#   {'source': 241, 'target': 239, 'value': 1.09},
#   {'source': 242, 'target': 239, 'value': 1.09},
#   {'source': 243, 'target': 244, 'value': 1.09},
#   {'source': 245, 'target': 246, 'value': 1.09},
#   {'source': 247, 'target': 246, 'value': 1.09},
#   {'source': 248, 'target': 246, 'value': 1.09},
#   {'source': 249, 'target': 246, 'value': 1.09},
#   {'source': 250, 'target': 246, 'value': 1.09},
#   {'source': 251, 'target': 246, 'value': 1.09},
#   {'source': 252, 'target': 246, 'value': 1.09},
#   {'source': 253, 'target': 246, 'value': 1.09},
#   {'source': 254, 'target': 246, 'value': 1.09},
#   {'source': 255, 'target': 256, 'value': 1.09},
#   {'source': 257, 'target': 256, 'value': 1.09},
#   {'source': 258, 'target': 256, 'value': 1.09},
#   {'source': 259, 'target': 256, 'value': 1.09},
#   {'source': 260, 'target': 256, 'value': 1.09},
#   {'source': 8, 'target': 261, 'value': 1.09},
#   {'source': 111, 'target': 261, 'value': 1.09},
#   {'source': 262, 'target': 261, 'value': 1.09},
#   {'source': 263, 'target': 261, 'value': 1.09},
#   {'source': 264, 'target': 265, 'value': 1.09},
#   {'source': 266, 'target': 267, 'value': 1.09},
#   {'source': 268, 'target': 267, 'value': 1.09},
#   {'source': 269, 'target': 270, 'value': 1.09},
#   {'source': 17, 'target': 271, 'value': 1.09},
#   {'source': 103, 'target': 271, 'value': 1.09},
#   {'source': 272, 'target': 271, 'value': 1.09},
#   {'source': 273, 'target': 271, 'value': 1.09},
#   {'source': 274, 'target': 271, 'value': 1.09},
#   {'source': 275, 'target': 271, 'value': 1.09},
#   {'source': 276, 'target': 271, 'value': 1.09},
#   {'source': 277, 'target': 271, 'value': 1.09},
#   {'source': 278, 'target': 271, 'value': 1.09},
#   {'source': 279, 'target': 271, 'value': 1.09},
#   {'source': 280, 'target': 271, 'value': 1.09},
#   {'source': 281, 'target': 271, 'value': 1.09},
#   {'source': 282, 'target': 271, 'value': 1.09},
#   {'source': 283, 'target': 271, 'value': 1.09},
#   {'source': 284, 'target': 271, 'value': 1.09},
#   {'source': 285, 'target': 271, 'value': 1.09},
#   {'source': 286, 'target': 271, 'value': 1.09},
#   {'source': 287, 'target': 271, 'value': 1.09},
#   {'source': 288, 'target': 271, 'value': 1.09},
#   {'source': 289, 'target': 271, 'value': 1.09},
#   {'source': 290, 'target': 271, 'value': 1.09},
#   {'source': 291, 'target': 292, 'value': 1.09},
#   {'source': 293, 'target': 292, 'value': 1.09},
#   {'source': 294, 'target': 295, 'value': 1.09},
#   {'source': 296, 'target': 297, 'value': 1.09},
#   {'source': 298, 'target': 297, 'value': 1.09},
#   {'source': 299, 'target': 297, 'value': 1.09},
#   {'source': 300, 'target': 297, 'value': 1.09},
#   {'source': 301, 'target': 297, 'value': 1.09},
#   {'source': 302, 'target': 297, 'value': 1.09},
#   {'source': 303, 'target': 304, 'value': 1.09},
#   {'source': 305, 'target': 306, 'value': 1.09},
#   {'source': 307, 'target': 255, 'value': 1.09},
#   {'source': 308, 'target': 255, 'value': 1.09},
#   {'source': 309, 'target': 255, 'value': 1.09},
#   {'source': 310, 'target': 255, 'value': 1.09},
#   {'source': 244, 'target': 311, 'value': 1.09},
#   {'source': 312, 'target': 311, 'value': 1.09},
#   {'source': 313, 'target': 311, 'value': 1.09},
#   {'source': 314, 'target': 311, 'value': 1.09},
#   {'source': 315, 'target': 311, 'value': 1.09},
#   {'source': 316, 'target': 154, 'value': 1.09},
#   {'source': 317, 'target': 318, 'value': 1.09},
#   {'source': 319, 'target': 318, 'value': 1.09},
#   {'source': 320, 'target': 318, 'value': 1.09},
#   {'source': 321, 'target': 322, 'value': 1.09},
#   {'source': 323, 'target': 322, 'value': 1.09},
#   {'source': 324, 'target': 325, 'value': 1.09},
#   {'source': 108, 'target': 325, 'value': 1.09},
#   {'source': 326, 'target': 325, 'value': 1.09},
#   {'source': 327, 'target': 325, 'value': 1.09},
#   {'source': 328, 'target': 325, 'value': 1.09},
#   {'source': 329, 'target': 330, 'value': 1.09},
#   {'source': 331, 'target': 330, 'value': 1.09},
#   {'source': 332, 'target': 333, 'value': 1.09},
#   {'source': 334, 'target': 333, 'value': 1.09},
#   {'source': 335, 'target': 333, 'value': 1.09},
#   {'source': 336, 'target': 337, 'value': 1.09},
#   {'source': 338, 'target': 31, 'value': 1.09},
#   {'source': 339, 'target': 31, 'value': 1.09},
#   {'source': 340, 'target': 341, 'value': 1.09},
#   {'source': 342, 'target': 341, 'value': 1.09},
#   {'source': 343, 'target': 341, 'value': 1.09},
#   {'source': 344, 'target': 341, 'value': 1.09},
#   {'source': 345, 'target': 341, 'value': 1.09},
#   {'source': 346, 'target': 165, 'value': 1.09},
#   {'source': 347, 'target': 181, 'value': 1.09},
#   {'source': 348, 'target': 181, 'value': 1.09},
#   {'source': 349, 'target': 240, 'value': 1.09},
#   {'source': 350, 'target': 351, 'value': 1.09},
#   {'source': 352, 'target': 351, 'value': 1.09},
#   {'source': 353, 'target': 351, 'value': 1.09},
#   {'source': 354, 'target': 351, 'value': 1.09},
#   {'source': 355, 'target': 351, 'value': 1.09},
#   {'source': 356, 'target': 351, 'value': 1.09},
#   {'source': 357, 'target': 351, 'value': 1.09},
#   {'source': 358, 'target': 351, 'value': 1.09},
#   {'source': 359, 'target': 351, 'value': 1.09},
#   {'source': 360, 'target': 351, 'value': 1.09},
#   {'source': 361, 'target': 351, 'value': 1.09},
#   {'source': 362, 'target': 363, 'value': 1.09},
#   {'source': 364, 'target': 363, 'value': 1.09},
#   {'source': 365, 'target': 363, 'value': 1.09},
#   {'source': 366, 'target': 219, 'value': 1.09},
#   {'source': 367, 'target': 368, 'value': 1.09},
#   {'source': 369, 'target': 368, 'value': 1.09},
#   {'source': 243, 'target': 368, 'value': 1.09},
#   {'source': 370, 'target': 291, 'value': 1.09},
#   {'source': 371, 'target': 291, 'value': 1.09},
#   {'source': 372, 'target': 373, 'value': 1.09},
#   {'source': 374, 'target': 373, 'value': 1.09},
#   {'source': 375, 'target': 376, 'value': 1.09},
#   {'source': 377, 'target': 376, 'value': 1.09},
#   {'source': 378, 'target': 11, 'value': 1.09},
#   {'source': 379, 'target': 380, 'value': 1.09},
#   {'source': 381, 'target': 380, 'value': 1.09},
#   {'source': 382, 'target': 380, 'value': 1.09},
#   {'source': 383, 'target': 380, 'value': 1.09},
#   {'source': 384, 'target': 380, 'value': 1.09},
#   {'source': 385, 'target': 380, 'value': 1.09},
#   {'source': 386, 'target': 380, 'value': 1.09},
#   {'source': 387, 'target': 380, 'value': 1.09},
#   {'source': 388, 'target': 380, 'value': 1.09},
#   {'source': 389, 'target': 380, 'value': 1.09},
#   {'source': 390, 'target': 391, 'value': 1.09},
#   {'source': 114, 'target': 392, 'value': 1.09},
#   {'source': 393, 'target': 392, 'value': 1.09},
#   {'source': 394, 'target': 392, 'value': 1.09},
#   {'source': 395, 'target': 392, 'value': 1.09},
#   {'source': 396, 'target': 392, 'value': 1.09},
#   {'source': 397, 'target': 392, 'value': 1.09},
#   {'source': 398, 'target': 392, 'value': 1.09},
#   {'source': 399, 'target': 392, 'value': 1.09},
#   {'source': 400, 'target': 392, 'value': 1.09},
#   {'source': 401, 'target': 392, 'value': 1.09},
#   {'source': 402, 'target': 403, 'value': 1.09},
#   {'source': 226, 'target': 403, 'value': 1.09},
#   {'source': 228, 'target': 403, 'value': 1.09},
#   {'source': 404, 'target': 403, 'value': 1.09},
#   {'source': 405, 'target': 403, 'value': 1.09},
#   {'source': 406, 'target': 403, 'value': 1.09},
#   {'source': 407, 'target': 16, 'value': 1.09},
#   {'source': 10, 'target': 408, 'value': 1.09},
#   {'source': 20, 'target': 408, 'value': 1.09},
#   {'source': 25, 'target': 408, 'value': 1.09},
#   {'source': 306, 'target': 408, 'value': 1.09},
#   {'source': 409, 'target': 408, 'value': 1.09},
#   {'source': 410, 'target': 408, 'value': 1.09},
#   {'source': 411, 'target': 408, 'value': 1.09},
#   {'source': 412, 'target': 408, 'value': 1.09},
#   {'source': 413, 'target': 408, 'value': 1.09},
#   {'source': 414, 'target': 408, 'value': 1.09},
#   {'source': 415, 'target': 408, 'value': 1.09},
#   {'source': 416, 'target': 408, 'value': 1.09},
#   {'source': 417, 'target': 408, 'value': 1.09},
#   {'source': 418, 'target': 408, 'value': 1.09},
#   {'source': 419, 'target': 408, 'value': 1.09},
#   {'source': 420, 'target': 408, 'value': 1.09},
#   {'source': 421, 'target': 408, 'value': 1.09},
#   {'source': 422, 'target': 408, 'value': 1.09},
#   {'source': 423, 'target': 408, 'value': 1.09},
#   {'source': 424, 'target': 408, 'value': 1.09},
#   {'source': 425, 'target': 408, 'value': 1.09},
#   {'source': 426, 'target': 408, 'value': 1.09},
#   {'source': 427, 'target': 408, 'value': 1.09},
#   {'source': 428, 'target': 408, 'value': 1.09},
#   {'source': 429, 'target': 408, 'value': 1.09},
#   {'source': 430, 'target': 408, 'value': 1.09},
#   {'source': 431, 'target': 432, 'value': 1.09},
#   {'source': 433, 'target': 432, 'value': 1.09},
#   {'source': 401, 'target': 432, 'value': 1.09},
#   {'source': 434, 'target': 115, 'value': 1.09},
#   {'source': 435, 'target': 436, 'value': 1.09},
#   {'source': 437, 'target': 438, 'value': 1.09},
#   {'source': 439, 'target': 438, 'value': 1.09},
#   {'source': 440, 'target': 438, 'value': 1.09},
#   {'source': 441, 'target': 438, 'value': 1.09},
#   {'source': 442, 'target': 438, 'value': 1.09},
#   {'source': 443, 'target': 438, 'value': 1.09},
#   {'source': 444, 'target': 438, 'value': 1.09},
#   {'source': 445, 'target': 276, 'value': 1.09},
#   {'source': 446, 'target': 276, 'value': 1.09},
#   {'source': 447, 'target': 276, 'value': 1.09},
#   {'source': 448, 'target': 276, 'value': 1.09},
#   {'source': 449, 'target': 276, 'value': 1.09},
#   {'source': 450, 'target': 276, 'value': 1.09},
#   {'source': 451, 'target': 276, 'value': 1.09},
#   {'source': 452, 'target': 276, 'value': 1.09},
#   {'source': 453, 'target': 410, 'value': 1.09},
#   {'source': 97, 'target': 454, 'value': 1.09},
#   {'source': 455, 'target': 454, 'value': 1.09},
#   {'source': 456, 'target': 454, 'value': 1.09},
#   {'source': 457, 'target': 454, 'value': 1.09},
#   {'source': 458, 'target': 454, 'value': 1.09},
#   {'source': 117, 'target': 454, 'value': 1.09},
#   {'source': 459, 'target': 454, 'value': 1.09},
#   {'source': 460, 'target': 454, 'value': 1.09},
#   {'source': 461, 'target': 454, 'value': 1.09},
#   {'source': 462, 'target': 454, 'value': 1.09},
#   {'source': 463, 'target': 454, 'value': 1.09},
#   {'source': 464, 'target': 454, 'value': 1.09},
#   {'source': 465, 'target': 454, 'value': 1.09},
#   {'source': 466, 'target': 454, 'value': 1.09},
#   {'source': 467, 'target': 454, 'value': 1.09},
#   {'source': 468, 'target': 454, 'value': 1.09},
#   {'source': 469, 'target': 277, 'value': 1.09},
#   {'source': 470, 'target': 471, 'value': 1.09},
#   {'source': 472, 'target': 471, 'value': 1.09},
#   {'source': 322, 'target': 473, 'value': 1.09},
#   {'source': 474, 'target': 473, 'value': 1.09},
#   {'source': 475, 'target': 476, 'value': 1.09},
#   {'source': 70, 'target': 394, 'value': 1.09},
#   {'source': 477, 'target': 394, 'value': 1.09},
#   {'source': 359, 'target': 394, 'value': 1.09},
#   {'source': 478, 'target': 479, 'value': 1.09},
#   {'source': 480, 'target': 479, 'value': 1.09},
#   {'source': 481, 'target': 482, 'value': 1.09},
#   {'source': 483, 'target': 484, 'value': 1.09},
#   {'source': 485, 'target': 486, 'value': 1.09},
#   {'source': 487, 'target': 488, 'value': 1.09},
#   {'source': 489, 'target': 488, 'value': 1.09},
#   {'source': 490, 'target': 488, 'value': 1.09},
#   {'source': 491, 'target': 488, 'value': 1.09},
#   {'source': 492, 'target': 488, 'value': 1.09},
#   {'source': 493, 'target': 488, 'value': 1.09},
#   {'source': 494, 'target': 488, 'value': 1.09},
#   {'source': 380, 'target': 488, 'value': 1.09},
#   {'source': 495, 'target': 488, 'value': 1.09},
#   {'source': 496, 'target': 488, 'value': 1.09},
#   {'source': 497, 'target': 488, 'value': 1.09},
#   {'source': 498, 'target': 488, 'value': 1.09},
#   {'source': 499, 'target': 488, 'value': 1.09},
#   {'source': 500, 'target': 488, 'value': 1.09},
#   {'source': 501, 'target': 488, 'value': 1.09},
#   {'source': 502, 'target': 488, 'value': 1.09},
#   {'source': 503, 'target': 488, 'value': 1.09},
#   {'source': 504, 'target': 488, 'value': 1.09},
#   {'source': 505, 'target': 488, 'value': 1.09},
#   {'source': 506, 'target': 488, 'value': 1.09},
#   {'source': 507, 'target': 488, 'value': 1.09},
#   {'source': 508, 'target': 488, 'value': 1.09},
#   {'source': 509, 'target': 488, 'value': 1.09},
#   {'source': 510, 'target': 488, 'value': 1.09},
#   {'source': 511, 'target': 488, 'value': 1.09},
#   {'source': 512, 'target': 488, 'value': 1.09},
#   {'source': 513, 'target': 488, 'value': 1.09},
#   {'source': 514, 'target': 488, 'value': 1.09},
#   {'source': 515, 'target': 488, 'value': 1.09},
#   {'source': 516, 'target': 488, 'value': 1.09},
#   {'source': 517, 'target': 488, 'value': 1.09},
#   {'source': 518, 'target': 488, 'value': 1.09},
#   {'source': 519, 'target': 488, 'value': 1.09},
#   {'source': 520, 'target': 488, 'value': 1.09},
#   {'source': 123, 'target': 521, 'value': 1.09},
#   {'source': 522, 'target': 521, 'value': 1.09},
#   {'source': 392, 'target': 521, 'value': 1.09},
#   {'source': 523, 'target': 521, 'value': 1.09},
#   {'source': 524, 'target': 521, 'value': 1.09},
#   {'source': 525, 'target': 521, 'value': 1.09},
#   {'source': 526, 'target': 521, 'value': 1.09},
#   {'source': 527, 'target': 521, 'value': 1.09},
#   {'source': 528, 'target': 521, 'value': 1.09},
#   {'source': 529, 'target': 521, 'value': 1.09},
#   {'source': 530, 'target': 521, 'value': 1.09},
#   {'source': 531, 'target': 521, 'value': 1.09},
#   {'source': 532, 'target': 521, 'value': 1.09},
#   {'source': 533, 'target': 521, 'value': 1.09},
#   {'source': 68, 'target': 534, 'value': 1.09},
#   {'source': 84, 'target': 534, 'value': 1.09},
#   {'source': 85, 'target': 534, 'value': 1.09},
#   {'source': 535, 'target': 536, 'value': 1.09},
#   {'source': 537, 'target': 536, 'value': 1.09},
#   {'source': 538, 'target': 536, 'value': 1.09},
#   {'source': 180, 'target': 200, 'value': 1.09},
#   {'source': 539, 'target': 200, 'value': 1.09},
#   {'source': 540, 'target': 200, 'value': 1.09},
#   {'source': 541, 'target': 200, 'value': 1.09},
#   {'source': 542, 'target': 200, 'value': 1.09},
#   {'source': 543, 'target': 544, 'value': 1.09},
#   {'source': 545, 'target': 163, 'value': 1.09},
#   {'source': 546, 'target': 163, 'value': 1.09},
#   {'source': 547, 'target': 163, 'value': 1.09},
#   {'source': 548, 'target': 163, 'value': 1.09},
#   {'source': 549, 'target': 163, 'value': 1.09},
#   {'source': 550, 'target': 163, 'value': 1.09},
#   {'source': 551, 'target': 163, 'value': 1.09},
#   {'source': 270, 'target': 158, 'value': 1.09},
#   {'source': 552, 'target': 158, 'value': 1.09},
#   {'source': 553, 'target': 554, 'value': 1.09},
#   {'source': 555, 'target': 554, 'value': 1.09},
#   {'source': 556, 'target': 557, 'value': 1.09},
#   {'source': 558, 'target': 559, 'value': 1.09},
#   {'source': 560, 'target': 561, 'value': 1.09},
#   {'source': 562, 'target': 561, 'value': 1.09},
#   {'source': 563, 'target': 561, 'value': 1.09},
#   {'source': 564, 'target': 326, 'value': 1.09},
#   {'source': 565, 'target': 326, 'value': 1.09},
#   {'source': 566, 'target': 326, 'value': 1.09},
#   {'source': 146, 'target': 567, 'value': 1.09},
#   {'source': 239, 'target': 567, 'value': 1.09},
#   {'source': 330, 'target': 567, 'value': 1.09},
#   {'source': 554, 'target': 567, 'value': 1.09},
#   {'source': 559, 'target': 567, 'value': 1.09},
#   {'source': 568, 'target': 567, 'value': 1.09},
#   {'source': 569, 'target': 567, 'value': 1.09},
#   {'source': 570, 'target': 567, 'value': 1.09},
#   {'source': 571, 'target': 567, 'value': 1.09},
#   {'source': 572, 'target': 567, 'value': 1.09},
#   {'source': 573, 'target': 567, 'value': 1.09},
#   {'source': 574, 'target': 567, 'value': 1.09},
#   {'source': 575, 'target': 567, 'value': 1.09},
#   {'source': 576, 'target': 567, 'value': 1.09},
#   {'source': 577, 'target': 567, 'value': 1.09},
#   {'source': 578, 'target': 579, 'value': 1.09},
#   {'source': 580, 'target': 579, 'value': 1.09},
#   {'source': 581, 'target': 579, 'value': 1.09},
#   {'source': 582, 'target': 579, 'value': 1.09},
#   {'source': 583, 'target': 579, 'value': 1.09},
#   {'source': 584, 'target': 585, 'value': 1.09},
#   {'source': 586, 'target': 585, 'value': 1.09},
#   {'source': 587, 'target': 585, 'value': 1.09},
#   {'source': 588, 'target': 585, 'value': 1.09},
#   {'source': 335, 'target': 545, 'value': 1.09},
#   {'source': 159, 'target': 589, 'value': 1.09},
#   {'source': 590, 'target': 589, 'value': 1.09},
#   {'source': 591, 'target': 589, 'value': 1.09},
#   {'source': 592, 'target': 589, 'value': 1.09},
#   {'source': 593, 'target': 589, 'value': 1.09},
#   {'source': 594, 'target': 589, 'value': 1.09},
#   {'source': 168, 'target': 568, 'value': 1.09},
#   {'source': 595, 'target': 568, 'value': 1.09},
#   {'source': 596, 'target': 568, 'value': 1.09},
#   {'source': 597, 'target': 568, 'value': 1.09},
#   {'source': 598, 'target': 568, 'value': 1.09},
#   {'source': 599, 'target': 568, 'value': 1.09},
#   {'source': 600, 'target': 568, 'value': 1.09},
#   {'source': 63, 'target': 601, 'value': 1.09},
#   {'source': 602, 'target': 601, 'value': 1.09},
#   {'source': 363, 'target': 603, 'value': 1.09},
#   {'source': 604, 'target': 603, 'value': 1.09},
#   {'source': 605, 'target': 603, 'value': 1.09},
#   {'source': 606, 'target': 603, 'value': 1.09},
#   {'source': 607, 'target': 372, 'value': 1.09},
#   {'source': 608, 'target': 372, 'value': 1.09},
#   {'source': 609, 'target': 372, 'value': 1.09},
#   {'source': 610, 'target': 372, 'value': 1.09},
#   {'source': 611, 'target': 372, 'value': 1.09},
#   {'source': 612, 'target': 372, 'value': 1.09},
#   {'source': 613, 'target': 372, 'value': 1.09},
#   {'source': 614, 'target': 372, 'value': 1.09},
#   {'source': 615, 'target': 372, 'value': 1.09},
#   {'source': 616, 'target': 372, 'value': 1.09},
#   {'source': 617, 'target': 372, 'value': 1.09},
#   {'source': 618, 'target': 372, 'value': 1.09},
#   {'source': 619, 'target': 620, 'value': 1.09},
#   {'source': 621, 'target': 620, 'value': 1.09},
#   {'source': 622, 'target': 623, 'value': 1.09},
#   {'source': 624, 'target': 203, 'value': 1.09},
#   {'source': 625, 'target': 203, 'value': 1.09},
#   {'source': 626, 'target': 203, 'value': 1.09},
#   {'source': 627, 'target': 203, 'value': 1.09},
#   {'source': 628, 'target': 203, 'value': 1.09},
#   {'source': 629, 'target': 630, 'value': 1.09},
#   {'source': 631, 'target': 630, 'value': 1.09},
#   {'source': 632, 'target': 630, 'value': 1.09},
#   {'source': 633, 'target': 630, 'value': 1.09},
#   {'source': 634, 'target': 62, 'value': 1.09},
#   {'source': 635, 'target': 62, 'value': 1.09},
#   {'source': 636, 'target': 62, 'value': 1.09},
#   {'source': 637, 'target': 62, 'value': 1.09},
#   {'source': 638, 'target': 639, 'value': 1.09},
#   {'source': 640, 'target': 639, 'value': 1.09},
#   {'source': 72, 'target': 639, 'value': 1.09},
#   {'source': 641, 'target': 639, 'value': 1.09},
#   {'source': 642, 'target': 639, 'value': 1.09},
#   {'source': 297, 'target': 639, 'value': 1.09},
#   {'source': 643, 'target': 639, 'value': 1.09},
#   {'source': 644, 'target': 639, 'value': 1.09},
#   {'source': 579, 'target': 639, 'value': 1.09},
#   {'source': 645, 'target': 639, 'value': 1.09},
#   {'source': 646, 'target': 639, 'value': 1.09},
#   {'source': 647, 'target': 639, 'value': 1.09},
#   {'source': 648, 'target': 639, 'value': 1.09},
#   {'source': 649, 'target': 639, 'value': 1.09},
#   {'source': 650, 'target': 651, 'value': 1.09},
#   {'source': 652, 'target': 651, 'value': 1.09},
#   {'source': 653, 'target': 26, 'value': 1.09},
#   {'source': 654, 'target': 414, 'value': 1.09},
#   {'source': 655, 'target': 414, 'value': 1.09},
#   {'source': 656, 'target': 657, 'value': 1.09},
#   {'source': 658, 'target': 657, 'value': 1.09},
#   {'source': 659, 'target': 660, 'value': 1.09},
#   {'source': 661, 'target': 660, 'value': 1.09},
#   {'source': 662, 'target': 535, 'value': 1.09},
#   {'source': 663, 'target': 126, 'value': 1.09},
#   {'source': 364, 'target': 604, 'value': 1.09},
#   {'source': 56, 'target': 64, 'value': 1.09},
#   {'source': 408, 'target': 405, 'value': 1.09},
#   {'source': 664, 'target': 405, 'value': 1.09},
#   {'source': 665, 'target': 405, 'value': 1.09},
#   {'source': 666, 'target': 590, 'value': 1.09},
#   {'source': 667, 'target': 590, 'value': 1.09},
#   {'source': 668, 'target': 204, 'value': 1.09},
#   {'source': 669, 'target': 204, 'value': 1.09},
#   {'source': 670, 'target': 204, 'value': 1.09},
#   {'source': 671, 'target': 204, 'value': 1.09},
#   {'source': 672, 'target': 204, 'value': 1.09},
#   {'source': 673, 'target': 456, 'value': 1.09},
#   {'source': 318, 'target': 456, 'value': 1.09},
#   {'source': 674, 'target': 456, 'value': 1.09},
#   {'source': 675, 'target': 456, 'value': 1.09},
#   {'source': 319, 'target': 456, 'value': 1.09},
#   {'source': 676, 'target': 456, 'value': 1.09},
#   {'source': 677, 'target': 456, 'value': 1.09},
#   {'source': 678, 'target': 456, 'value': 1.09},
#   {'source': 528, 'target': 456, 'value': 1.09},
#   {'source': 679, 'target': 456, 'value': 1.09},
#   {'source': 680, 'target': 456, 'value': 1.09},
#   {'source': 681, 'target': 456, 'value': 1.09},
#   {'source': 682, 'target': 456, 'value': 1.09},
#   {'source': 683, 'target': 127, 'value': 1.09},
#   {'source': 684, 'target': 127, 'value': 1.09},
#   {'source': 685, 'target': 127, 'value': 1.09},
#   {'source': 686, 'target': 127, 'value': 1.09},
#   {'source': 687, 'target': 127, 'value': 1.09},
#   {'source': 688, 'target': 127, 'value': 1.09},
#   {'source': 689, 'target': 127, 'value': 1.09},
#   {'source': 690, 'target': 127, 'value': 1.09},
#   {'source': 209, 'target': 691, 'value': 1.09},
#   {'source': 692, 'target': 691, 'value': 1.09},
#   {'source': 693, 'target': 694, 'value': 1.09},
#   {'source': 695, 'target': 694, 'value': 1.09},
#   {'source': 696, 'target': 245, 'value': 1.09},
#   {'source': 697, 'target': 698, 'value': 1.09},
#   {'source': 211, 'target': 698, 'value': 1.09},
#   {'source': 699, 'target': 698, 'value': 1.09},
#   {'source': 700, 'target': 698, 'value': 1.09},
#   {'source': 333, 'target': 698, 'value': 1.09},
#   {'source': 701, 'target': 698, 'value': 1.09},
#   {'source': 603, 'target': 698, 'value': 1.09},
#   {'source': 702, 'target': 698, 'value': 1.09},
#   {'source': 480, 'target': 698, 'value': 1.09},
#   {'source': 703, 'target': 698, 'value': 1.09},
#   {'source': 704, 'target': 698, 'value': 1.09},
#   {'source': 705, 'target': 698, 'value': 1.09},
#   {'source': 706, 'target': 698, 'value': 1.09},
#   {'source': 707, 'target': 698, 'value': 1.09},
#   {'source': 708, 'target': 698, 'value': 1.09},
#   {'source': 709, 'target': 698, 'value': 1.09},
#   {'source': 710, 'target': 698, 'value': 1.09},
#   {'source': 711, 'target': 19, 'value': 1.09},
#   {'source': 712, 'target': 668, 'value': 1.09},
#   {'source': 713, 'target': 714, 'value': 1.09},
#   {'source': 484, 'target': 715, 'value': 1.09},
#   {'source': 716, 'target': 715, 'value': 1.09},
#   {'source': 180, 'target': 205, 'value': 1.09},
#   {'source': 488, 'target': 205, 'value': 1.09},
#   {'source': 539, 'target': 205, 'value': 1.09},
#   {'source': 540, 'target': 205, 'value': 1.09},
#   {'source': 541, 'target': 205, 'value': 1.09},
#   {'source': 717, 'target': 446, 'value': 1.09},
#   {'source': 718, 'target': 446, 'value': 1.09},
#   {'source': 27, 'target': 537, 'value': 1.09},
#   {'source': 311, 'target': 537, 'value': 1.09},
#   {'source': 719, 'target': 537, 'value': 1.09},
#   {'source': 720, 'target': 721, 'value': 1.09},
#   {'source': 369, 'target': 313, 'value': 1.09},
#   {'source': 722, 'target': 610, 'value': 1.09},
#   {'source': 723, 'target': 610, 'value': 1.09},
#   {'source': 724, 'target': 610, 'value': 1.09},
#   {'source': 725, 'target': 610, 'value': 1.09},
#   {'source': 726, 'target': 610, 'value': 1.09},
#   {'source': 530, 'target': 727, 'value': 1.09},
#   {'source': 728, 'target': 729, 'value': 1.09},
#   {'source': 271, 'target': 257, 'value': 1.09},
#   {'source': 341, 'target': 257, 'value': 1.09},
#   {'source': 730, 'target': 257, 'value': 1.09},
#   {'source': 731, 'target': 257, 'value': 1.09},
#   {'source': 732, 'target': 257, 'value': 1.09},
#   {'source': 733, 'target': 257, 'value': 1.09},
#   {'source': 224, 'target': 734, 'value': 1.09},
#   {'source': 735, 'target': 734, 'value': 1.09},
#   {'source': 736, 'target': 737, 'value': 1.09},
#   {'source': 738, 'target': 737, 'value': 1.09},
#   {'source': 739, 'target': 737, 'value': 1.09},
#   {'source': 740, 'target': 737, 'value': 1.09},
#   {'source': 741, 'target': 737, 'value': 1.09},
#   {'source': 742, 'target': 737, 'value': 1.09},
#   {'source': 743, 'target': 737, 'value': 1.09},
#   {'source': 744, 'target': 737, 'value': 1.09},
#   {'source': 745, 'target': 737, 'value': 1.09},
#   {'source': 746, 'target': 737, 'value': 1.09},
#   {'source': 747, 'target': 329, 'value': 1.09},
#   {'source': 748, 'target': 329, 'value': 1.09},
#   {'source': 749, 'target': 329, 'value': 1.09},
#   {'source': 750, 'target': 329, 'value': 1.09},
#   {'source': 751, 'target': 248, 'value': 1.09},
#   {'source': 752, 'target': 248, 'value': 1.09},
#   {'source': 479, 'target': 248, 'value': 1.09},
#   {'source': 753, 'target': 248, 'value': 1.09},
#   {'source': 754, 'target': 248, 'value': 1.09},
#   {'source': 755, 'target': 756, 'value': 1.09},
#   {'source': 757, 'target': 758, 'value': 1.09},
#   {'source': 759, 'target': 758, 'value': 1.09},
#   {'source': 760, 'target': 758, 'value': 1.09},
#   {'source': 761, 'target': 758, 'value': 1.09},
#   {'source': 762, 'target': 116, 'value': 1.09},
#   {'source': 763, 'target': 356, 'value': 1.09},
#   {'source': 351, 'target': 764, 'value': 1.09},
#   {'source': 32, 'target': 458, 'value': 1.09},
#   {'source': 765, 'target': 458, 'value': 1.09},
#   {'source': 766, 'target': 458, 'value': 1.09},
#   {'source': 714, 'target': 458, 'value': 1.09},
#   {'source': 742, 'target': 458, 'value': 1.09},
#   {'source': 767, 'target': 458, 'value': 1.09},
#   {'source': 768, 'target': 458, 'value': 1.09},
#   {'source': 769, 'target': 458, 'value': 1.09},
#   {'source': 770, 'target': 458, 'value': 1.09},
#   {'source': 771, 'target': 569, 'value': 1.09},
#   {'source': 256, 'target': 249, 'value': 1.09},
#   {'source': 772, 'target': 249, 'value': 1.09},
#   {'source': 773, 'target': 249, 'value': 1.09},
#   {'source': 774, 'target': 730, 'value': 1.09},
#   {'source': 775, 'target': 730, 'value': 1.09},
#   {'source': 776, 'target': 716, 'value': 1.09},
#   {'source': 777, 'target': 716, 'value': 1.09},
#   {'source': 778, 'target': 716, 'value': 1.09},
#   {'source': 367, 'target': 314, 'value': 1.09},
#   {'source': 373, 'target': 779, 'value': 1.09},
#   {'source': 521, 'target': 779, 'value': 1.09},
#   {'source': 639, 'target': 779, 'value': 1.09},
#   {'source': 764, 'target': 779, 'value': 1.09},
#   {'source': 780, 'target': 779, 'value': 1.09},
#   {'source': 781, 'target': 779, 'value': 1.09},
#   {'source': 782, 'target': 779, 'value': 1.09},
#   {'source': 783, 'target': 779, 'value': 1.09},
#   {'source': 784, 'target': 779, 'value': 1.09},
#   {'source': 785, 'target': 779, 'value': 1.09},
#   {'source': 786, 'target': 772, 'value': 1.09},
#   {'source': 787, 'target': 772, 'value': 1.09},
#   {'source': 788, 'target': 772, 'value': 1.09},
#   {'source': 651, 'target': 772, 'value': 1.09},
#   {'source': 789, 'target': 772, 'value': 1.09},
#   {'source': 790, 'target': 772, 'value': 1.09},
#   {'source': 791, 'target': 772, 'value': 1.09},
#   {'source': 792, 'target': 772, 'value': 1.09},
#   {'source': 793, 'target': 772, 'value': 1.09},
#   {'source': 794, 'target': 772, 'value': 1.09},
#   {'source': 144, 'target': 447, 'value': 1.09},
#   {'source': 795, 'target': 447, 'value': 1.09},
#   {'source': 796, 'target': 447, 'value': 1.09},
#   {'source': 797, 'target': 798, 'value': 1.09},
#   {'source': 799, 'target': 798, 'value': 1.09},
#   {'source': 800, 'target': 798, 'value': 1.09},
#   {'source': 801, 'target': 798, 'value': 1.09},
#   {'source': 802, 'target': 798, 'value': 1.09},
#   {'source': 803, 'target': 798, 'value': 1.09},
#   {'source': 804, 'target': 678, 'value': 1.09},
#   {'source': 805, 'target': 678, 'value': 1.09},
#   {'source': 806, 'target': 278, 'value': 1.09},
#   {'source': 807, 'target': 278, 'value': 1.09},
#   {'source': 808, 'target': 278, 'value': 1.09},
#   {'source': 809, 'target': 278, 'value': 1.09},
#   {'source': 810, 'target': 278, 'value': 1.09},
#   {'source': 811, 'target': 611, 'value': 1.09},
#   {'source': 812, 'target': 611, 'value': 1.09},
#   {'source': 813, 'target': 611, 'value': 1.09},
#   {'source': 814, 'target': 611, 'value': 1.09},
#   {'source': 815, 'target': 611, 'value': 1.09},
#   {'source': 816, 'target': 817, 'value': 1.09},
#   {'source': 818, 'target': 817, 'value': 1.09},
#   {'source': 819, 'target': 817, 'value': 1.09},
#   {'source': 820, 'target': 817, 'value': 1.09},
#   {'source': 821, 'target': 279, 'value': 1.09},
#   {'source': 822, 'target': 279, 'value': 1.09},
#   {'source': 823, 'target': 279, 'value': 1.09},
#   {'source': 824, 'target': 279, 'value': 1.09},
#   {'source': 304, 'target': 731, 'value': 1.09},
#   {'source': 825, 'target': 731, 'value': 1.09},
#   {'source': 826, 'target': 280, 'value': 1.09},
#   {'source': 827, 'target': 280, 'value': 1.09},
#   {'source': 828, 'target': 258, 'value': 1.09},
#   {'source': 829, 'target': 258, 'value': 1.09},
#   {'source': 365, 'target': 605, 'value': 1.09},
#   {'source': 830, 'target': 831, 'value': 1.09},
#   {'source': 832, 'target': 831, 'value': 1.09},
#   {'source': 833, 'target': 459, 'value': 1.09},
#   {'source': 834, 'target': 835, 'value': 1.09},
#   {'source': 836, 'target': 837, 'value': 1.09},
#   {'source': 838, 'target': 417, 'value': 1.09},
#   {'source': 839, 'target': 417, 'value': 1.09},
#   {'source': 840, 'target': 417, 'value': 1.09},
#   {'source': 9, 'target': 417, 'value': 1.09},
#   {'source': 841, 'target': 417, 'value': 1.09},
#   {'source': 842, 'target': 417, 'value': 1.09},
#   {'source': 843, 'target': 417, 'value': 1.09},
#   {'source': 844, 'target': 417, 'value': 1.09},
#   {'source': 845, 'target': 417, 'value': 1.09},
#   {'source': 846, 'target': 417, 'value': 1.09},
#   {'source': 847, 'target': 417, 'value': 1.09},
#   {'source': 848, 'target': 481, 'value': 1.09},
#   {'source': 197, 'target': 160, 'value': 1.09},
#   {'source': 849, 'target': 850, 'value': 1.09},
#   {'source': 851, 'target': 850, 'value': 1.09},
#   {'source': 852, 'target': 853, 'value': 1.09},
#   {'source': 854, 'target': 853, 'value': 1.09},
#   {'source': 855, 'target': 856, 'value': 1.09},
#   {'source': 857, 'target': 856, 'value': 1.09},
#   {'source': 858, 'target': 448, 'value': 1.09},
#   {'source': 859, 'target': 448, 'value': 1.09},
#   {'source': 860, 'target': 861, 'value': 1.09},
#   {'source': 862, 'target': 861, 'value': 1.09},
#   {'source': 863, 'target': 861, 'value': 1.09},
#   {'source': 864, 'target': 861, 'value': 1.09},
#   {'source': 865, 'target': 861, 'value': 1.09},
#   {'source': 866, 'target': 861, 'value': 1.09},
#   {'source': 867, 'target': 861, 'value': 1.09},
#   {'source': 155, 'target': 868, 'value': 1.09},
#   {'source': 869, 'target': 868, 'value': 1.09},
#   {'source': 870, 'target': 871, 'value': 1.09},
#   {'source': 309, 'target': 871, 'value': 1.09},
#   {'source': 872, 'target': 873, 'value': 1.09},
#   {'source': 485, 'target': 873, 'value': 1.09},
#   {'source': 232, 'target': 396, 'value': 1.09},
#   {'source': 874, 'target': 396, 'value': 1.09},
#   {'source': 875, 'target': 396, 'value': 1.09},
#   {'source': 876, 'target': 396, 'value': 1.09},
#   {'source': 877, 'target': 396, 'value': 1.09},
#   {'source': 878, 'target': 396, 'value': 1.09},
#   {'source': 317, 'target': 396, 'value': 1.09},
#   {'source': 879, 'target': 396, 'value': 1.09},
#   {'source': 880, 'target': 396, 'value': 1.09},
#   {'source': 881, 'target': 396, 'value': 1.09},
#   {'source': 882, 'target': 396, 'value': 1.09},
#   {'source': 883, 'target': 396, 'value': 1.09},
#   {'source': 884, 'target': 396, 'value': 1.09},
#   {'source': 885, 'target': 396, 'value': 1.09},
#   {'source': 886, 'target': 790, 'value': 1.09},
#   {'source': 887, 'target': 331, 'value': 1.09},
#   {'source': 888, 'target': 331, 'value': 1.09},
#   {'source': 889, 'target': 331, 'value': 1.09},
#   {'source': 890, 'target': 433, 'value': 1.09},
#   {'source': 891, 'target': 433, 'value': 1.09},
#   {'source': 892, 'target': 893, 'value': 1.09},
#   {'source': 894, 'target': 893, 'value': 1.09},
#   {'source': 895, 'target': 893, 'value': 1.09},
#   {'source': 896, 'target': 780, 'value': 1.09},
#   {'source': 589, 'target': 780, 'value': 1.09},
#   {'source': 897, 'target': 780, 'value': 1.09},
#   {'source': 898, 'target': 591, 'value': 1.09},
#   {'source': 534, 'target': 591, 'value': 1.09},
#   {'source': 899, 'target': 591, 'value': 1.09},
#   {'source': 900, 'target': 188, 'value': 1.09},
#   {'source': 325, 'target': 188, 'value': 1.09},
#   {'source': 901, 'target': 188, 'value': 1.09},
#   {'source': 902, 'target': 188, 'value': 1.09},
#   {'source': 903, 'target': 188, 'value': 1.09},
#   {'source': 904, 'target': 233, 'value': 1.09},
#   {'source': 217, 'target': 460, 'value': 1.09},
#   {'source': 905, 'target': 460, 'value': 1.09},
#   {'source': 906, 'target': 460, 'value': 1.09},
#   {'source': 621, 'target': 460, 'value': 1.09},
#   {'source': 850, 'target': 905, 'value': 1.09},
#   {'source': 619, 'target': 905, 'value': 1.09},
#   {'source': 907, 'target': 596, 'value': 1.09},
#   {'source': 908, 'target': 596, 'value': 1.09},
#   {'source': 909, 'target': 910, 'value': 1.09},
#   {'source': 911, 'target': 912, 'value': 1.09},
#   {'source': 913, 'target': 912, 'value': 1.09},
#   {'source': 914, 'target': 912, 'value': 1.09},
#   {'source': 454, 'target': 781, 'value': 1.09},
#   {'source': 915, 'target': 781, 'value': 1.09},
#   {'source': 916, 'target': 781, 'value': 1.09},
#   {'source': 917, 'target': 29, 'value': 1.09},
#   {'source': 918, 'target': 29, 'value': 1.09},
#   {'source': 919, 'target': 29, 'value': 1.09},
#   {'source': 641, 'target': 527, 'value': 1.09},
#   {'source': 920, 'target': 527, 'value': 1.09},
#   {'source': 224, 'target': 527, 'value': 1.09},
#   {'source': 267, 'target': 527, 'value': 1.09},
#   {'source': 376, 'target': 527, 'value': 1.09},
#   {'source': 675, 'target': 527, 'value': 1.09},
#   {'source': 737, 'target': 527, 'value': 1.09},
#   {'source': 921, 'target': 527, 'value': 1.09},
#   {'source': 922, 'target': 527, 'value': 1.09},
#   {'source': 923, 'target': 527, 'value': 1.09},
#   {'source': 562, 'target': 527, 'value': 1.09},
#   {'source': 375, 'target': 527, 'value': 1.09},
#   {'source': 924, 'target': 527, 'value': 1.09},
#   {'source': 820, 'target': 527, 'value': 1.09},
#   {'source': 925, 'target': 527, 'value': 1.09},
#   {'source': 926, 'target': 527, 'value': 1.09},
#   {'source': 927, 'target': 527, 'value': 1.09},
#   {'source': 735, 'target': 527, 'value': 1.09},
#   {'source': 928, 'target': 929, 'value': 1.09},
#   {'source': 930, 'target': 929, 'value': 1.09},
#   {'source': 931, 'target': 929, 'value': 1.09},
#   {'source': 666, 'target': 929, 'value': 1.09},
#   {'source': 932, 'target': 695, 'value': 1.09},
#   {'source': 933, 'target': 695, 'value': 1.09},
#   {'source': 934, 'target': 695, 'value': 1.09},
#   {'source': 935, 'target': 419, 'value': 1.09},
#   {'source': 936, 'target': 189, 'value': 1.09},
#   {'source': 937, 'target': 938, 'value': 1.09},
#   {'source': 660, 'target': 938, 'value': 1.09},
#   {'source': 939, 'target': 938, 'value': 1.09},
#   {'source': 940, 'target': 938, 'value': 1.09},
#   {'source': 941, 'target': 942, 'value': 1.09},
#   {'source': 943, 'target': 420, 'value': 1.09},
#   {'source': 944, 'target': 420, 'value': 1.09},
#   {'source': 945, 'target': 420, 'value': 1.09},
#   {'source': 946, 'target': 420, 'value': 1.09},
#   {'source': 947, 'target': 420, 'value': 1.09},
#   {'source': 948, 'target': 420, 'value': 1.09},
#   {'source': 949, 'target': 21, 'value': 1.09},
#   {'source': 950, 'target': 612, 'value': 1.09},
#   {'source': 951, 'target': 612, 'value': 1.09},
#   {'source': 952, 'target': 953, 'value': 1.09},
#   {'source': 954, 'target': 953, 'value': 1.09},
#   {'source': 955, 'target': 250, 'value': 1.09},
#   {'source': 956, 'target': 250, 'value': 1.09},
#   {'source': 957, 'target': 250, 'value': 1.09},
#   {'source': 958, 'target': 250, 'value': 1.09},
#   {'source': 959, 'target': 250, 'value': 1.09},
#   {'source': 960, 'target': 250, 'value': 1.09},
#   {'source': 961, 'target': 250, 'value': 1.09},
#   {'source': 59, 'target': 962, 'value': 1.09},
#   {'source': 963, 'target': 962, 'value': 1.09},
#   {'source': 694, 'target': 962, 'value': 1.09},
#   {'source': 964, 'target': 962, 'value': 1.09},
#   {'source': 965, 'target': 503, 'value': 1.09},
#   {'source': 966, 'target': 503, 'value': 1.09},
#   {'source': 967, 'target': 190, 'value': 1.09},
#   {'source': 968, 'target': 190, 'value': 1.09},
#   {'source': 969, 'target': 251, 'value': 1.09},
#   {'source': 561, 'target': 251, 'value': 1.09},
#   {'source': 721, 'target': 251, 'value': 1.09},
#   {'source': 734, 'target': 251, 'value': 1.09},
#   {'source': 929, 'target': 251, 'value': 1.09},
#   {'source': 970, 'target': 251, 'value': 1.09},
#   {'source': 971, 'target': 251, 'value': 1.09},
#   {'source': 972, 'target': 251, 'value': 1.09},
#   {'source': 973, 'target': 251, 'value': 1.09},
#   {'source': 974, 'target': 251, 'value': 1.09},
#   {'source': 475, 'target': 283, 'value': 1.09},
#   {'source': 975, 'target': 283, 'value': 1.09},
#   {'source': 976, 'target': 767, 'value': 1.09},
#   {'source': 977, 'target': 767, 'value': 1.09},
#   {'source': 978, 'target': 767, 'value': 1.09},
#   {'source': 235, 'target': 767, 'value': 1.09},
#   {'source': 236, 'target': 767, 'value': 1.09},
#   {'source': 979, 'target': 767, 'value': 1.09},
#   {'source': 172, 'target': 112, 'value': 1.09},
#   {'source': 870, 'target': 112, 'value': 1.09},
#   {'source': 309, 'target': 112, 'value': 1.09},
#   {'source': 980, 'target': 811, 'value': 1.09},
#   {'source': 455, 'target': 811, 'value': 1.09},
#   {'source': 981, 'target': 664, 'value': 1.09},
#   {'source': 982, 'target': 664, 'value': 1.09},
#   {'source': 983, 'target': 664, 'value': 1.09},
#   {'source': 984, 'target': 664, 'value': 1.09},
#   {'source': 985, 'target': 664, 'value': 1.09},
#   {'source': 94, 'target': 421, 'value': 1.09},
#   {'source': 986, 'target': 421, 'value': 1.09},
#   {'source': 987, 'target': 421, 'value': 1.09},
#   {'source': 988, 'target': 421, 'value': 1.09},
#   {'source': 989, 'target': 421, 'value': 1.09},
#   {'source': 990, 'target': 421, 'value': 1.09},
#   {'source': 991, 'target': 284, 'value': 1.09},
#   {'source': 992, 'target': 732, 'value': 1.09},
#   {'source': 993, 'target': 732, 'value': 1.09},
#   {'source': 46, 'target': 774, 'value': 1.09},
#   {'source': 994, 'target': 774, 'value': 1.09},
#   {'source': 995, 'target': 774, 'value': 1.09},
#   {'source': 996, 'target': 774, 'value': 1.09},
#   {'source': 997, 'target': 774, 'value': 1.09},
#   {'source': 998, 'target': 14, 'value': 1.09},
#   {'source': 92, 'target': 999, 'value': 1.09},
#   {'source': 893, 'target': 999, 'value': 1.09},
#   {'source': 1000, 'target': 259, 'value': 1.09},
#   {'source': 1001, 'target': 259, 'value': 1.09},
#   {'source': 1002, 'target': 259, 'value': 1.09},
#   {'source': 1003, 'target': 259, 'value': 1.09},
#   {'source': 1004, 'target': 540, 'value': 1.09},
#   {'source': 1005, 'target': 825, 'value': 1.09},
#   {'source': 1006, 'target': 529, 'value': 1.09},
#   {'source': 713, 'target': 768, 'value': 1.09},
#   {'source': 1007, 'target': 768, 'value': 1.09},
# ...
#   {'group': 1, 'name': 'phosphoglycerate mutase content'},
#   {'group': 1, 'name': 'glutamine synthetase content'},
#   {'group': 1, 'name': 'brown rice protein'},
#   {'group': 1, 'name': 'polished rice protein content'},
#   {'group': 1, 'name': 'perodidase-71 content'},
#   {'group': 1, 'name': 'endosperm storage protein content'},
#   {'group': 1, 'name': 'white rice protein content'},
#   {'group': 1, 'name': 'NADH glutamate synthase content'},
#   {'group': 1, 'name': 'maysin content'},
#   {'group': 1, 'name': 'rubisco content'},
#   {'group': 1, 'name': 'rhizome branching number'},
#   {'group': 1, 'name': 'rhizome dry weight'},
#   {'group': 1, 'name': 'rhizome branching angle'},
#   {'group': 1, 'name': 'rhizome formation'},
#   {'group': 1, 'name': 'rhizome length'},
#   {'group': 1, 'name': 'rhizome number'},
#   {'group': 1, 'name': 'rhizome internode length'},
#   {'group': 1, 'name': 'rhizome internode number'},
#   {'group': 1, 'name': 'fruit size'},
#   {'group': 1, 'name': 'fruit diameter'},
#   {'group': 1, 'name': 'embryo hypocotyl morphology trait'},
#   {'group': 1, 'name': 'hypocotyl morphology trait'},
#   {'group': 1, 'name': 'seedling hypocotyl morphology trait'},
#   {'group': 1, 'name': 'plant ovary color'},
#   {'group': 1, 'name': 'root cracking'},
#   {'group': 1, 'name': 'root morphology trait'},
#   {'group': 1, 'name': 'root pulling force'},
#   {'group': 1, 'name': 'root shape'},
#   {'group': 1, 'name': 'rooting depth'},
#   {'group': 1, 'name': 'root volume'},
#   {'group': 1, 'name': 'penetrated to total root ratio'},
#   {'group': 1, 'name': 'root color'},
#   {'group': 1, 'name': 'root thickness'},
#   {'group': 1, 'name': 'root to shoot ratio'},
#   {'group': 1, 'name': 'root weight'},
#   {'group': 1, 'name': 'root penetration index'},
#   {'group': 1, 'name': 'root hair length'},
#   {'group': 1, 'name': 'root branching'},
#   {'group': 1, 'name': 'secondary branch number'},
#   {'group': 1, 'name': 'two-spotted spider mite resistance'},
#   {'group': 1, 'name': 'glucosamine content'},
#   {'group': 1, 'name': 'carbohydrate derivative content'},
#   {'group': 1, 'name': 'fruit weight'},
#   {'group': 1, 'name': 'dehulled grain weight'},
#   {'group': 1, 'name': 'abaxial stomatal frequency'},
#   {'group': 1, 'name': 'adaxial stomatal frequency'},
#   {'group': 1, 'name': 'pollen sterility'},
#   {'group': 1, 'name': 'mesocarp color'},
#   {'group': 1, 'name': 'mesocarp morphology trait'},
#   {'group': 1, 'name': 'osmotic response sensitivity'},
#   {'group': 1, 'name': 'deepwater stress'},
#   {'group': 1, 'name': 'drought related trait'},
#   {'group': 1, 'name': 'humidity related trait'},
#   {'group': 1, 'name': 'flooding related trait'},
#   {'group': 1, 'name': 'beta-glucanase activity trait'},
#   {'group': 1, 'name': 'Indole-3-acetic acid content'},
#   {'group': 1, 'name': 'auxin content'},
#   {'group': 1, 'name': 'bract morphology trait'},
#   {'group': 1, 'name': 'sporophyll morphology trait'},
#   {'group': 1, 'name': 'tepal morphology trait'},
#   {'group': 1, 'name': 'petal morphology trait'},
#   {'group': 1, 'name': 'pericarp morphology trait'},
#   {'group': 1, 'name': 'pericarp texture'},
#   {'group': 1, 'name': 'starch grain size'},
#   {'group': 1, 'name': 'grain quality trait'},
#   {'group': 1, 'name': 'crushed grain percentage'},
#   {'group': 1, 'name': 'bran percentage'},
#   {'group': 1, 'name': 'grain thickness'},
#   {'group': 1, 'name': 'cracked grain percentage'},
#   {'group': 1, 'name': 'starch yield'},
#   {'group': 1, 'name': 'starch grain shape'},
#   {'group': 1, 'name': 'grain density'},
#   {'group': 1, 'name': 'head rice'},
#   {'group': 1, 'name': 'milled rice'},
#   {'group': 1, 'name': 'petiole shape'},
#   {'group': 1, 'name': 'petiole length'},
#   {'group': 1, 'name': 'petiole color'},
#   {'group': 1, 'name': 'petiole size'},
#   {'group': 1, 'name': 'plant cell shape'},
#   {'group': 1, 'name': 'turgor pressure'},
#   {'group': 1, 'name': 'plant cell size'},
#   {'group': 1, 'name': 'cell organelle morphology trait'},
#   {'group': 1, 'name': 'sorghum stem borer resistance'},
#   {'group': 1, 'name': 'stem borer resistance'},
#   {'group': 1, 'name': 'axillary bud number'},
#   {'group': 1, 'name': 'axillary bud morphology trait'},
#   {'group': 1, 'name': 'axillary bud shape'},
#   {'group': 1, 'name': 'axillary bud prominence'},
#   {'group': 1, 'name': 'axillary bud size'},
#   {'group': 1, 'name': 'grain moisture'},
#   {'group': 1, 'name': 'seedling vigor'},
#   {'group': 1, 'name': 'stature or vigor trait'},
#   {'group': 1, 'name': 'cellulose content'},
#   {'group': 1, 'name': 'starchiness'},
#   {'group': 1, 'name': 'polysaccharide content'},
#   {'group': 1, 'name': 'oligosaccharide content'},
#   {'group': 1, 'name': 'beta-glucan content'},
#   {'group': 1, 'name': 'sugar content'},
#   {'group': 1, 'name': 'phyllome margin morphology trait'},
#   {'group': 1, 'name': 'seed morphology trait'},
#   {'group': 1, 'name': 'fruit morphology trait'},
#   {'group': 1, 'name': 'inflorescence bract morphology trait'},
#   {'group': 1, 'name': 'flower bract morphology trait'},
#   {'group': 1, 'name': '10-dehulled grain weight'},
#   {'group': 1, 'name': '100-dehulled grain weight'},
#   {'group': 1, 'name': '1000-dehulled grain weight'},
#   {'group': 1, 'name': 'plant trait'},
#   {'group': 1, 'name': 'plant growth and development trait'},
#   {'group': 1, 'name': 'biochemical trait'},
#   {'group': 1, 'name': 'other miscellaneous trait'},
#   {'group': 1, 'name': 'plant morphology trait'},
#   {'group': 1, 'name': 'sterility or fertility trait'},
#   {'group': 1, 'name': 'yield trait'},
#   {'group': 1, 'name': 'seed hardness'},
#   {'group': 1, 'name': 'seed texture'},
#   {'group': 1, 'name': 'seed color'},
#   {'group': 1, 'name': 'seed size'},
#   {'group': 1, 'name': 'seed length'},
#   {'group': 1, 'name': 'seed thickness'},
#   {'group': 1, 'name': 'hilum morphology trait'},
#   {'group': 1, 'name': 'seed shape'},
#   {'group': 1, 'name': 'seed width'},
#   {'group': 1, 'name': 'leaf vein size'},
#   {'group': 1, 'name': 'leaf midvein morphology trait'},
#   {'group': 1, 'name': 'ear infructescence number'},
#   {'group': 1, 'name': 'infructescence yield trait'},
#   {'group': 1, 'name': 'kernel number per ear'},
#   {'group': 1, 'name': 'rank number per ear'},
#   {'group': 1, 'name': 'kernel number per row'},
#   {'group': 1, 'name': 'kernel row number per ear'},
#   {'group': 1, 'name': 'kernel row length'},
#   {'group': 1, 'name': 'endosperm storage protein-1 content'},
#   {'group': 1, 'name': 'endosperm storage protein-2 content'},
#   {'group': 1, 'name': 'leaf length to width ratio'},
#   {'group': 1, 'name': 'leaf width'},
#   {'group': 1, 'name': 'leaf foliage rating'},
#   {'group': 1, 'name': 'leaf thickness'},
#   {'group': 1, 'name': 'leaf length'},
#   {'group': 1, 'name': 'oxidative stress'},
#   {'group': 1, 'name': 'growth media composition sensitivity'},
#   {'group': 1, 'name': 'plant growth hormone sensitivity'},
#   {'group': 1, 'name': 'pesticide sensitivity'},
#   {'group': 1, 'name': 'herbicide sensitivity'},
#   {'group': 1, 'name': 'dry fruit color'},
#   {'group': 1, 'name': 'fruit color'},
#   {'group': 1, 'name': 'fruit columella color'},
#   {'group': 1, 'name': 'milled grain color'},
#   {'group': 1, 'name': 'fruit color uniformity'},
#   {'group': 1, 'name': 'leaf erect'},
#   {'group': 1, 'name': 'leaf prostrate'},
#   {'group': 1, 'name': 'leaf penduloum'},
#   {'group': 1, 'name': 'leaf angle'},
#   {'group': 1, 'name': 'microsporophyll morphology trait'},
#   {'group': 1, 'name': 'leaf rolling time'},
#   {'group': 1, 'name': 'leaf rolling tolerance'},
#   {'group': 1, 'name': 'coleoptile color'},
#   {'group': 1, 'name': 'coleoptile length'},
#   {'group': 1, 'name': 'shoot potassium content'},
#   {'group': 1, 'name': 'potassium content'},
#   {'group': 1, 'name': 'potassium concentration'},
#   {'group': 1, 'name': 'lignin monomer content'},
#   {'group': 1, 'name': 'inflorescence bract number'},
#   {'group': 1, 'name': 'inflorescence bract development trait'},
#   {'group': 1, 'name': 'days to tassel'},
#   {'group': 1, 'name': 'male flowering'},
#   {'group': 1, 'name': 'panicle threshability'},
#   {'group': 1, 'name': 'panicle type'},
#   {'group': 1, 'name': 'panicle shape'},
#   {'group': 1, 'name': 'panicle base to lowest branch'},
#   {'group': 1, 'name': 'panicle compactness and shape'},
#   {'group': 1, 'name': 'panicle length'},
#   {'group': 1, 'name': 'panicle color'},
#   {'group': 1, 'name': 'panicle exsertion'},
#   {'group': 1, 'name': 'panicle size'},
#   {'group': 1, 'name': 'panicle number'},
#   {'group': 1, 'name': 'rice seedling blight disease resistance'},
#   {'group': 1, 'name': 'momilactone A content'},
#   {'group': 1, 'name': 'diterpenoid phytoalexin content'},
#   {'group': 1, 'name': 'momilactone B content'},
#   {'group': 1, 'name': 'potassium chlorate resistance'},
#   {'group': 1, 'name': 'salt sensitivity'},
#   {'group': 1, 'name': 'salt tolerance'},
#   {'group': 1, 'name': 'acid sensitivity'},
#   {'group': 1, 'name': 'growth media pH sensitivity'},
#   {'group': 1, 'name': 'alkali sensitivity'},
#   {'group': 1, 'name': 'plant embryo cotyledon morphology trait'},
#   {'group': 1, 'name': 'seedling cotyledon morphology trait'},
#   {'group': 1, 'name': 'chlorine sensitivity'},
#   {'group': 1, 'name': 'micronutrient sensitivity'},
#   {'group': 1, 'name': 'molybdenum sensitivity'},
#   {'group': 1, 'name': 'copper sensitivity'},
#   {'group': 1, 'name': 'iron sensitivity'},
#   {'group': 1, 'name': 'zinc sensitivity'},
#   {'group': 1, 'name': 'boron sensitivity'},
#   {'group': 1, 'name': 'manganese sensitivity'},
#   {'group': 1, 'name': 'macronutrient sensitivity'},
#   {'group': 1, 'name': 'secondary macronutrient sensitivity'},
#   {'group': 1, 'name': 'ectopic lodicule development'},
#   {'group': 1, 'name': 'lodicule development trait'},
#   {'group': 1, 'name': 'shoot apical meristem development'},
#   {'group': 1, 'name': 'shoot meristem development'},
#   {'group': 1, 'name': 'grain belly percent white'},
#   {'group': 1, 'name': 'glutinous endosperm'},
#   {'group': 1, 'name': 'grain core percent white'},
#   {'group': 1, 'name': 'brittle endosperm'},
#   {'group': 1, 'name': 'rough endosperm'},
#   {'group': 1, 'name': 'grain core area white'},
#   {'group': 1, 'name': 'etched endosperm'},
#   {'group': 1, 'name': 'shrunken endosperm'},
#   {'group': 1, 'name': 'floury endosperm'},
#   {'group': 1, 'name': 'dull endosperm'},
#   {'group': 1, 'name': 'endospermless'},
#   {'group': 1, 'name': 'sugary endosperm'},
#   {'group': 1, 'name': 'seed length to width ratio'},
#   {'group': 1, 'name': 'petiolule shape'},
#   {'group': 1, 'name': 'petiolule length'},
#   {'group': 1, 'name': 'petiolule color'},
#   {'group': 1, 'name': 'female fertility restoration trait'},
#   {'group': 1, 'name': 'male fertility restoration trait'},
#   {'group': 1, 'name': 'seedling height'},
#   {'group': 1, 'name': 'plant height'},
#   {'group': 1, 'name': 'relative plant height'},
#   {'group': 1, 'name': 'plant height uniformity'},
#   {'group': 1, 'name': 'albino plantlet differentiation frequency'},
#   {'group': 1, 'name': 'plant phenological trait'},
#   {'group': 1, 'name': 'stay green trait'},
#   {'group': 1, 'name': 'seedling growth and development trait'},
#   {'group': 1, 'name': 'inflorescence axis size'},
#   {'group': 1, 'name': 'inflorescence axis texture'},
#   {'group': 1, 'name': 'inflorescence axis angle'},
#   {'group': 1, 'name': 'inflorescence axis color'},
#   {'group': 1, 'name': 'alkali digestion'},
#   {'group': 1, 'name': 'flavonoid content'},
#   {'group': 1, 'name': 'ferulic acid content'},
#   {'group': 1, 'name': 'flag leaf lamina width'},
#   {'group': 1, 'name': 'penultimate leaf lamina width'},
#   {'group': 1, 'name': 'drought susceptibility index'},
#   {'group': 1, 'name': 'drought sensitivity'},
#   {'group': 1, 'name': 'leaf margin color'},
#   {'group': 1, 'name': 'leaf margin morphology trait'},
#   {'group': 1, 'name': 'leaf lamina margin morphology trait'},
#   {'group': 1, 'name': 'leaf margin serrated'},
#   {'group': 1, 'name': 'enzyme activity trait'},
#   {'group': 1, 'name': 'mineral and ion content related trait'},
#   {'group': 1, 'name': 'genic male sterility-thermo-photoperiod sensitive'},
#   {'group': 1, 'name': 'genic male sterility-thermo sensitive'},
#   {'group': 1, 'name': 'genic male sterility-photoperiod sensitive'},
#   {'group': 1, 'name': 'fruit hollowness'},
#   {'group': 1, 'name': 'fruit firmness'},
#   {'group': 1, 'name': 'fruit crispness'},
#   {'group': 1, 'name': 'juiciness'},
#   {'group': 1, 'name': 'locular tissue trait'},
#   {'group': 1, 'name': 'groat percentage'},
#   {'group': 1, 'name': 'fruit senescing quality trait'},
#   {'group': 1, 'name': 'fruit flavor trait'},
#   {'group': 1, 'name': 'xylem color'},
#   {'group': 1, 'name': 'vascular tissue morphology trait'},
#   {'group': 1, 'name': 'phloem color'},
#   {'group': 1, 'name': 'secondary xylem volumetric density'},
#   {'group': 1, 'name': 'seedling hypocotyl length'},
#   {'group': 1, 'name': 'seedling hypocotyl color'},
#   {'group': 1, 'name': 'seedling hypocotyl size'},
#   {'group': 1, 'name': 'spike width'},
#   {'group': 1, 'name': 'basal tiller number'},
#   {'group': 1, 'name': 'light intensity sensitivity'},
#   {'group': 1, 'name': 'light sensitivity'},
#   {'group': 1, 'name': 'photoperiod sensitivity trait'},
#   {'group': 1, 'name': 'light quality sensitivity'},
#   {'group': 1, 'name': 'floral bract number'},
#   {'group': 1, 'name': 'floral bract development trait'},
#   {'group': 1, 'name': 'spikelet length'},
#   {'group': 1, 'name': 'spikelet length to width ratio'},
#   {'group': 1, 'name': 'spikelet weight'},
#   {'group': 1, 'name': 'spikelet density'},
#   {'group': 1, 'name': 'spikelet width'},
#   {'group': 1, 'name': 'spikelet fertility'},
#   {'group': 1, 'name': 'tertiary branch number'},
#   {'group': 1, 'name': 'heat tolerance'},
#   {'group': 1, 'name': 'cold tolerance'},
#   {'group': 1, 'name': 'grain length'},
#   {'group': 1, 'name': 'fruit length'},
#   {'group': 1, 'name': 'fruit curved length'},
#   {'group': 1, 'name': 'trichome hirsute'},
#   {'group': 1, 'name': 'trichome canescent'},
#   {'group': 1, 'name': 'trichome capillary'},
#   {'group': 1, 'name': 'trichome clavate'},
#   {'group': 1, 'name': 'trichome acircular'},
#   {'group': 1, 'name': 'trichome appressed'},
#   {'group': 1, 'name': 'trichome ensiform'},
#   {'group': 1, 'name': 'stem internode morphology trait'},
#   {'group': 1, 'name': 'stem internode bent'},
#   {'group': 1, 'name': 'stem internode color'},
#   {'group': 1, 'name': 'leaf blast disease resistance'},
#   {'group': 1, 'name': 'panicle blast disease resistance'},
#   {'group': 1, 'name': 'branch angle'},
#   {'group': 1, 'name': 'branch position'},
#   {'group': 1, 'name': 'stem epidermis color'},
#   {'group': 1, 'name': 'stem cortex color'},
#   {'group': 1, 'name': 'endosperm morphology trait'},
#   {'group': 1, 'name': 'aleurone layer morphology trait'},
#   {'group': 1, 'name': 'endocarp morphology trait'},
#   {'group': 1, 'name': 'seed coat morphology trait'},
#   {'group': 1, 'name': 'leaf necrosis tolerance'},
#   {'group': 1, 'name': 'starch concentration'},
#   {'group': 1, 'name': 'amylose to amylopectin ratio'},
#   {'group': 1, 'name': 'sucrose content'},
#   {'group': 1, 'name': 'amylose content'},
#   {'group': 1, 'name': 'oxygen sensitivity'},
#   {'group': 1, 'name': 'infructescence position'},
#   {'group': 1, 'name': 'seed set percent'},
#   {'group': 1, 'name': 'infructescence weight'},
#   {'group': 1, 'name': 'fruit number trait'},
#   {'group': 1, 'name': 'ear infructescence morphology trait'},
#   {'group': 1, 'name': 'tassel inflorescence type'},
#   {'group': 1, 'name': 'tassel inflorescence diameter'},
#   {'group': 1, 'name': 'tassel inflorescence circumference'},
#   {'group': 1, 'name': 'tassel inflorescence color'},
#   {'group': 1, 'name': 'tassel inflorescence height'},
#   {'group': 1, 'name': 'leaf trichome density'},
#   {'group': 1, 'name': 'tepal number'},
#   {'group': 1, 'name': 'tepal color'},
#   {'group': 1, 'name': 'inflorescence bract color'},
#   {'group': 1, 'name': 'involucral bract spine presence'},
#   {'group': 1, 'name': 'inflorescence bract cover'},
#   {'group': 1, 'name': 'inflorescence bract length'},
#   {'group': 1, 'name': 'corolla color'},
#   {'group': 1, 'name': 'whole plant size'},
#   ...]}
