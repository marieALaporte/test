# %%
from IPython.core.display import display, HTML
from string import Template
import json, random

# %%
HTML('''
<script src="lib/sigmajs/sigma.min.js"></script>
<script src="js/sigma-add-method-neighbors.js"></script>
''')
# Out:
# <script src="lib/sigmajs/sigma.min.js"></script>
# <script src="js/sigma-add-method-neighbors.js"></script>

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# #CONSTRUCT
# #{
# #    ?x rdfs:subClassOf ?o .
# #}
# SELECT ?x ?xlabel ?o ?olabel
# WHERE
# {
#     ?x rdfs:subClassOf ?o .
#     filter(!isblank(?o))
#     filter(!regex(str(?o), "PATO"))
#     filter(regex(str(?o), "TO"))
#     ?x rdfs:label ?xlabel .
#     ?o rdfs:label ?olabel.
# }' > toSigma.json

# %%
with open('to.json') as data_file:    
    data = json.load(data_file)
    list = data["results"]["bindings"]
    
    graph = {"nodes": [], "edges": []}
    j = 0
    
    xcord = random.uniform(0,1)
    ycord = random.uniform(0,1)
    for entry in list:
        x = 0
        o = 0
        
        for e in graph["nodes"]:
            if e["id"] == entry["x"]["value"]:
                x=1
            if e["id"] == entry["o"]["value"]:
                o=1
        if x==0:
            #graph["nodes"].append( {"name": entry["xlabel"]["value"], "group": 1} )
             graph['nodes'].append({
            "id": entry["x"]["value"],
          #  "label": entry["xlabel"]["value"],
            "x": xcord,
            "y": ycord,
            "size": 1
        })
             xcord+=1
             ycord+=1
                
        if o==0:
         graph['nodes'].append({
            "id": entry["o"]["value"],
           # "label": entry["olabel"]["value"],
            "x": xcord,
            "y": ycord,
            "size": 1
        })
         xcord+=1
         ycord+=1
            
        if  entry["x"]["value"] != entry["o"]["value"]:
            #graph["links"].append( {"source": entry["xlabel"]["value"], "target": entry["olabel"]["value"], "value": 1.09} )
            j +=1
            graph['edges'].append({
                "id": "e" + str(j),
                "source": entry["x"]["value"],
                "target": entry["o"]["value"], 
                "size": 100
            })

# %%
graph
# Out:
# {'edges': [{'id': 'e1',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006045',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e2',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002666',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e3',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000645',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e4',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000626',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e5',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020114',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e6',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001025',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001024'},
#   {'id': 'e7',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006019',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006018'},
#   {'id': 'e8',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000970',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000800'},
#   {'id': 'e9',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000994',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000845'},
#   {'id': 'e10',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000275',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000845'},
#   {'id': 'e11',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000950',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000845'},
#   {'id': 'e12',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000979',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000845'},
#   {'id': 'e13',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001014',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000505'},
#   {'id': 'e14',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000891',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000505'},
#   {'id': 'e15',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000142',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000050'},
#   {'id': 'e16',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006035',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000050'},
#   {'id': 'e17',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002751',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000050'},
#   {'id': 'e18',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000052',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000050'},
#   {'id': 'e19',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020069',
#    'target': 'http://purl.obolibrary.org/obo/TO_0001002'},
#   {'id': 'e20',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000111',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000106'},
#   {'id': 'e21',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000389',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000106'},
#   {'id': 'e22',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000199',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000106'},
#   {'id': 'e23',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000580',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000106'},
#   {'id': 'e24',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000307',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006006'},
#   {'id': 'e25',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020079',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000301'},
#   {'id': 'e26',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020119',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000301'},
#   {'id': 'e27',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002701',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000301'},
#   {'id': 'e28',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020078',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000301'},
#   {'id': 'e29',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020118',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000301'},
#   {'id': 'e30',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000375',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002731'},
#   {'id': 'e31',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020021',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020024'},
#   {'id': 'e32',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020022',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020024'},
#   {'id': 'e33',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020023',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020024'},
#   {'id': 'e34',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020033',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e35',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020038',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e36',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001000',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e37',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020034',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e38',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001001',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e39',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000978',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e40',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000221',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e41',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000474',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e42',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020036',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000869'},
#   {'id': 'e43',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000594',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000593'},
#   {'id': 'e44',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000595',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000593'},
#   {'id': 'e45',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000544',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000758'},
#   {'id': 'e46',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000773',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000758'},
#   {'id': 'e47',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000772',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000758'},
#   {'id': 'e48',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002759',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000396'},
#   {'id': 'e49',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000589',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000396'},
#   {'id': 'e50',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000450',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000396'},
#   {'id': 'e51',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020002',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000396'},
#   {'id': 'e52',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000449',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000396'},
#   {'id': 'e53',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000619',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000615'},
#   {'id': 'e54',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000253',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000615'},
#   {'id': 'e55',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012004',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e56',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020115',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e57',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020116',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e58',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020117',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e59',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012005',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e60',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012009',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012006'},
#   {'id': 'e61',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000288',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000703'},
#   {'id': 'e62',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000338',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000703'},
#   {'id': 'e63',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000336',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000703'},
#   {'id': 'e64',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000193',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000064'},
#   {'id': 'e65',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000189',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000064'},
#   {'id': 'e66',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000195',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000064'},
#   {'id': 'e67',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000451',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000472'},
#   {'id': 'e68',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000558',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000472'},
#   {'id': 'e69',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000539',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000472'},
#   {'id': 'e70',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000538',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000472'},
#   {'id': 'e71',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000194',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000193'},
#   {'id': 'e72',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000113',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000193'},
#   {'id': 'e73',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000940',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000798'},
#   {'id': 'e74',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000939',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000798'},
#   {'id': 'e75',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006002',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002673'},
#   {'id': 'e76',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002674',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002673'},
#   {'id': 'e77',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000571',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000568'},
#   {'id': 'e78',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000552',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000568'},
#   {'id': 'e79',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000616',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000492'},
#   {'id': 'e80',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020084',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000492'},
#   {'id': 'e81',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000561',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000559'},
#   {'id': 'e82',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000813',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000785'},
#   {'id': 'e83',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000812',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000785'},
#   {'id': 'e84',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002612',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002611'},
#   {'id': 'e85',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002613',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002611'},
#   {'id': 'e86',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000489',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e87',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000491',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e88',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000228',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e89',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000611',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e90',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000087',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e91',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000490',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000488'},
#   {'id': 'e92',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000892',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e93',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000132',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e94',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000051',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e95',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000879',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e96',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020083',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e97',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000056',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e98',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000549',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e99',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000560',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e100',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001035',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e101',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002639',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e102',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000893',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e103',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000634',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e104',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000952',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e105',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000577',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e106',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000576',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e107',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000404',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000361'},
#   {'id': 'e108',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000531',
#    'target': 'http://purl.obolibrary.org/obo/TO_1000022'},
#   {'id': 'e109',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000187',
#    'target': 'http://purl.obolibrary.org/obo/TO_1000022'},
#   {'id': 'e110',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000214',
#    'target': 'http://purl.obolibrary.org/obo/TO_1000022'},
#   {'id': 'e111',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012008',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012004'},
#   {'id': 'e112',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012007',
#    'target': 'http://purl.obolibrary.org/obo/TO_0012004'},
#   {'id': 'e113',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000720',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000719'},
#   {'id': 'e114',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002716',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002717'},
#   {'id': 'e115',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000294',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002717'},
#   {'id': 'e116',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000226',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002717'},
#   {'id': 'e117',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000046',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000036'},
#   {'id': 'e118',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000042',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000036'},
#   {'id': 'e119',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000647',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000705'},
#   {'id': 'e120',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000011',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000248'},
#   {'id': 'e121',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000008',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000248'},
#   {'id': 'e122',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000102',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000248'},
#   {'id': 'e123',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000722',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002686'},
#   {'id': 'e124',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002755',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002686'},
#   {'id': 'e125',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002687',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002686'},
#   {'id': 'e126',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000728',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002686'},
#   {'id': 'e127',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000084',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000985'},
#   {'id': 'e128',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000205',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000348'},
#   {'id': 'e129',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020030',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000055'},
#   {'id': 'e130',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020029',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000055'},
#   {'id': 'e131',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002602',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000223'},
#   {'id': 'e132',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002659',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000223'},
#   {'id': 'e133',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002610',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000223'},
#   {'id': 'e134',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000745',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000742'},
#   {'id': 'e135',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000744',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000742'},
#   {'id': 'e136',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000743',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000742'},
#   {'id': 'e137',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000746',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000742'},
#   {'id': 'e138',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000020',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e139',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000213',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e140',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000088',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e141',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000386',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e142',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000147',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e143',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020067',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e144',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000413',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000148'},
#   {'id': 'e145',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000568',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e146',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000361',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e147',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000782',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e148',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000346',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e149',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000195',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e150',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000740',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e151',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002756',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e152',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000921',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e153',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000567',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e154',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000517',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e155',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000776',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000739'},
#   {'id': 'e156',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002715',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002714'},
#   {'id': 'e157',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000943',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000944'},
#   {'id': 'e158',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000242',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000236'},
#   {'id': 'e159',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000063',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000236'},
#   {'id': 'e160',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000347',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000236'},
#   {'id': 'e161',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000054',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000236'},
#   {'id': 'e162',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000112',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000236'},
#   {'id': 'e163',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000339',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000051'},
#   {'id': 'e164',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000200',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000051'},
#   {'id': 'e165',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000061',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000051'},
#   {'id': 'e166',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002731',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000397'},
#   {'id': 'e167',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020103',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000227'},
#   {'id': 'e168',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000516',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000227'},
#   {'id': 'e169',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000508',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000227'},
#   {'id': 'e170',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001012',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000227'},
#   {'id': 'e171',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000586',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000227'},
#   {'id': 'e172',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001016',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e173',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012003',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e174',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000298',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e175',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000293',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e176',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000295',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e177',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0012002',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000495'},
#   {'id': 'e178',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000617',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000707'},
#   {'id': 'e179',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000989',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000988'},
#   {'id': 'e180',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001010',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000241'},
#   {'id': 'e181',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000049',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000310'},
#   {'id': 'e182',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000047',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000310'},
#   {'id': 'e183',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000266',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e184',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000462',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e185',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000062',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e186',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000097',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e187',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000696',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e188',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000211',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000489'},
#   {'id': 'e189',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002689',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000835'},
#   {'id': 'e190',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002724',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000835'},
#   {'id': 'e191',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002721',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000835'},
#   {'id': 'e192',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000642',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000835'},
#   {'id': 'e193',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000169',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000026'},
#   {'id': 'e194',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000021',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e195',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000844',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e196',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002683',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e197',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000836',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e198',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000911',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e199',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000843',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e200',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000398',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e201',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000837',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e202',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000840',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000839'},
#   {'id': 'e203',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006009',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000736'},
#   {'id': 'e204',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000747',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000736'},
#   {'id': 'e205',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000753',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000736'},
#   {'id': 'e206',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000862',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000736'},
#   {'id': 'e207',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000738',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000736'},
#   {'id': 'e208',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006018',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000927'},
#   {'id': 'e209',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002611',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000927'},
#   {'id': 'e210',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000656',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000927'},
#   {'id': 'e211',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000655',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000927'},
#   {'id': 'e212',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020094',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020093'},
#   {'id': 'e213',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000689',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000685'},
#   {'id': 'e214',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002645',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000685'},
#   {'id': 'e215',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000726',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000723'},
#   {'id': 'e216',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000505',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e217',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000492',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e218',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006014',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e219',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000446',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e220',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000826',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e221',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000828',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e222',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000419',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e223',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000541',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e224',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002637',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e225',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000824',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e226',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000085',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e227',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000709',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e228',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000825',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e229',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000652',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e230',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002722',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e231',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000540',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e232',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000925',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e233',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000493',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e234',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000721',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e235',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000504',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e236',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000326',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000748'},
#   {'id': 'e237',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000124',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000832'},
#   {'id': 'e238',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002757',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000832'},
#   {'id': 'e239',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000019',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000537'},
#   {'id': 'e240',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020100',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e241',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020101',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e242',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020099',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e243',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000511',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e244',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000527',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e245',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000514',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020096'},
#   {'id': 'e246',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006012',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000867'},
#   {'id': 'e247',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000623',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000643'},
#   {'id': 'e248',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006011',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006009'},
#   {'id': 'e249',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000857',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006009'},
#   {'id': 'e250',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006010',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006009'},
#   {'id': 'e251',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000856',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006009'},
#   {'id': 'e252',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000026',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000218'},
#   {'id': 'e253',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000245',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000218'},
#   {'id': 'e254',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000415',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000218'},
#   {'id': 'e255',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000060',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000218'},
#   {'id': 'e256',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000353',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000218'},
#   {'id': 'e257',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020098',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000011'},
#   {'id': 'e258',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000710',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000325'},
#   {'id': 'e259',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000610',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000325'},
#   {'id': 'e260',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002680',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000325'},
#   {'id': 'e261',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002695',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002697'},
#   {'id': 'e262',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002696',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002697'},
#   {'id': 'e263',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000630',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000784'},
#   {'id': 'e264',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000785',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000784'},
#   {'id': 'e265',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000954',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000784'},
#   {'id': 'e266',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0011004',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000784'},
#   {'id': 'e267',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000846',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000784'},
#   {'id': 'e268',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000765',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000764'},
#   {'id': 'e269',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000884',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000764'},
#   {'id': 'e270',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000714',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000198'},
#   {'id': 'e271',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000234',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000198'},
#   {'id': 'e272',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000230',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000198'},
#   {'id': 'e273',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000287',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002730'},
#   {'id': 'e274',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000932',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000307'},
#   {'id': 'e275',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000300',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000307'},
#   {'id': 'e276',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000573',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000864'},
#   {'id': 'e277',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002608',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000864'},
#   {'id': 'e278',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006040',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000864'},
#   {'id': 'e279',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002607',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000864'},
#   {'id': 'e280',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002604',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000864'},
#   {'id': 'e281',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000569',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000205'},
#   {'id': 'e282',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000127',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000213'},
#   {'id': 'e283',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000126',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000213'},
#   {'id': 'e284',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000367',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002724'},
#   {'id': 'e285',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000434',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e286',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000355',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e287',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000425',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e288',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000430',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e289',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000428',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e290',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000296',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e291',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000515',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e292',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0010001',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e293',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000202',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e294',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000243',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e295',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000096',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000250'},
#   {'id': 'e296',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000123',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000120'},
#   {'id': 'e297',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000125',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000120'},
#   {'id': 'e298',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000122',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000120'},
#   {'id': 'e299',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000320',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000298'},
#   {'id': 'e300',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000110',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000232'},
#   {'id': 'e301',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000350',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000232'},
#   {'id': 'e302',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000169',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000232'},
#   {'id': 'e303',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002732',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000124'},
#   {'id': 'e304',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002733',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000124'},
#   {'id': 'e305',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000168',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000164'},
#   {'id': 'e306',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000179',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000164'},
#   {'id': 'e307',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002741',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002739'},
#   {'id': 'e308',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002764',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002739'},
#   {'id': 'e309',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000225',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000994'},
#   {'id': 'e310',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020011',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e311',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000663',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e312',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020013',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e313',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000662',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e314',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000691',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e315',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020014',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e316',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000255',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e317',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000673',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e318',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020012',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e319',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020015',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000664'},
#   {'id': 'e320',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006049',
#    'target': 'http://purl.obolibrary.org/obo/TO_0020089'},
#   {'id': 'e321',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000488',
# ...
#    'target': 'http://purl.obolibrary.org/obo/TO_0000769'},
#   {'id': 'e895',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000759',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000769'},
#   {'id': 'e896',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000781',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000769'},
#   {'id': 'e897',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000638',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000804'},
#   {'id': 'e898',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0001004',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000346'},
#   {'id': 'e899',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000460',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000075'},
#   {'id': 'e900',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002650',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000075'},
#   {'id': 'e901',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000229',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000075'},
#   {'id': 'e902',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000265',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000075'},
#   {'id': 'e903',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006026',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006025'},
#   {'id': 'e904',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002768',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e905',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000563',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e906',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000501',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e907',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000625',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e908',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000564',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e909',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000180',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000657'},
#   {'id': 'e910',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006034',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006035'},
#   {'id': 'e911',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000259',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000432'},
#   {'id': 'e912',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000303',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000432'},
#   {'id': 'e913',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000734',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002626'},
#   {'id': 'e914',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002744',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002626'},
#   {'id': 'e915',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000918',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e916',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000914',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e917',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000915',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e918',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000916',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e919',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000913',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e920',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000912',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e921',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000917',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000911'},
#   {'id': 'e922',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000758',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000756'},
#   {'id': 'e923',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000000',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000756'},
#   {'id': 'e924',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000757',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000756'},
#   {'id': 'e925',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000426',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000756'},
#   {'id': 'e926',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000468',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000074'},
#   {'id': 'e927',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000477',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000074'},
#   {'id': 'e928',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000009',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000740'},
#   {'id': 'e929',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000008',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000740'},
#   {'id': 'e930',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000018',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e931',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000906',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e932',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000948',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e933',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000945',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e934',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000470',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e935',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000017',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e936',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000575',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e937',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000942',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e938',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000946',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e939',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000838',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000843'},
#   {'id': 'e940',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000070',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000652'},
#   {'id': 'e941',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002663',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000652'},
#   {'id': 'e942',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000702',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e943',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000372',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e944',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000328',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e945',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000097',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e946',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000696',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e947',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000196',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006007'},
#   {'id': 'e948',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002659',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002613'},
#   {'id': 'e949',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006024',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002613'},
#   {'id': 'e950',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006010',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002613'},
#   {'id': 'e951',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000015',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002657'},
#   {'id': 'e952',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000605',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002657'},
#   {'id': 'e953',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000004',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000920'},
#   {'id': 'e954',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000455',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000920'},
#   {'id': 'e955',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000583',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000920'},
#   {'id': 'e956',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000894',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000920'},
#   {'id': 'e957',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000976',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000920'},
#   {'id': 'e958',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000798',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e959',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000814',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e960',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000799',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e961',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000796',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e962',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000795',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e963',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000797',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000788'},
#   {'id': 'e964',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006066',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002722'},
#   {'id': 'e965',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006041',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000865'},
#   {'id': 'e966',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000574',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000865'},
#   {'id': 'e967',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000869',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000816'},
#   {'id': 'e968',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000819',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000816'},
#   {'id': 'e969',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0020120',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000816'},
#   {'id': 'e970',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000818',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000816'},
#   {'id': 'e971',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000817',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000816'},
#   {'id': 'e972',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000951',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000950'},
#   {'id': 'e973',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000113',
#    'target': 'http://purl.obolibrary.org/obo/TO_1000012'},
#   {'id': 'e974',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000207',
#    'target': 'http://purl.obolibrary.org/obo/TO_1000012'},
#   {'id': 'e975',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002614',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000862'},
#   {'id': 'e976',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002600',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000862'},
#   {'id': 'e977',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002615',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000862'},
#   {'id': 'e978',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006038',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000862'},
#   {'id': 'e979',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000292',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000013'},
#   {'id': 'e980',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000215',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000868'},
#   {'id': 'e981',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0002641',
#    'target': 'http://purl.obolibrary.org/obo/TO_0002642'},
#   {'id': 'e982',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000297',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006003'},
#   {'id': 'e983',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006005',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006003'},
#   {'id': 'e984',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006004',
#    'target': 'http://purl.obolibrary.org/obo/TO_0006003'},
#   {'id': 'e985',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000537',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e986',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000860',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e987',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000861',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e988',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000274',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e989',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000859',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e990',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000858',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e991',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000881',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000499'},
#   {'id': 'e992',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000064',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e993',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000559',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e994',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000708',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e995',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_1000012',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e996',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000737',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e997',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0006062',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000398'},
#   {'id': 'e998',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000276',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000394'},
#   {'id': 'e999',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000188',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000394'},
#   {'id': 'e1000',
#    'size': 100,
#    'source': 'http://purl.obolibrary.org/obo/TO_0000458',
#    'target': 'http://purl.obolibrary.org/obo/TO_0000394'},
#   ...],
#  'nodes': []}

# %%
js_text_template = Template(open('js/sigma-graph.js','r').read())

js_text = js_text_template.substitute({'graph_data': json.dumps(graph),
                                       'container': 'graph-div'})

html_template = Template('''
<div id="graph-div" style="height:400px"></div>
<script> $js_text </script>
''')
HTML(html_template.substitute({'js_text': js_text}))
# Out:
# <div id="graph-div" style="height:400px"></div>
# <script> var g = {"edges": [{"source": "http://purl.obolibrary.org/obo/TO_0006045", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e1", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0002666", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e2", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000645", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e3", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000626", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e4", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020114", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e5", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0001025", "target": "http://purl.obolibrary.org/obo/TO_0001024", "id": "e6", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0006019", "target": "http://purl.obolibrary.org/obo/TO_0006018", "id": "e7", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000970", "target": "http://purl.obolibrary.org/obo/TO_0000800", "id": "e8", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000994", "target": "http://purl.obolibrary.org/obo/TO_0000845", "id": "e9", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000275", "target": "http://purl.obolibrary.org/obo/TO_0000845", "id": "e10", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000950", "target": "http://purl.obolibrary.org/obo/TO_0000845", "id": "e11", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000979", "target": "http://purl.obolibrary.org/obo/TO_0000845", "id": "e12", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0001014", "target": "http://purl.obolibrary.org/obo/TO_0000505", "id": "e13", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000891", "target": "http://purl.obolibrary.org/obo/TO_0000505", "id": "e14", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000142", "target": "http://purl.obolibrary.org/obo/TO_0000050", "id": "e15", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0006035", "target": "http://purl.obolibrary.org/obo/TO_0000050", "id": "e16", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0002751", "target": "http://purl.obolibrary.org/obo/TO_0000050", "id": "e17", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000052", "target": "http://purl.obolibrary.org/obo/TO_0000050", "id": "e18", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020069", "target": "http://purl.obolibrary.org/obo/TO_0001002", "id": "e19", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000111", "target": "http://purl.obolibrary.org/obo/TO_0000106", "id": "e20", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000389", "target": "http://purl.obolibrary.org/obo/TO_0000106", "id": "e21", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000199", "target": "http://purl.obolibrary.org/obo/TO_0000106", "id": "e22", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000580", "target": "http://purl.obolibrary.org/obo/TO_0000106", "id": "e23", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0000307", "target": "http://purl.obolibrary.org/obo/TO_0006006", "id": "e24", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020079", "target": "http://purl.obolibrary.org/obo/TO_0000301", "id": "e25", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020119", "target": "http://purl.obolibrary.org/obo/TO_0000301", "id": "e26", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0002701", "target": "http://purl.obolibrary.org/obo/TO_0000301", "id": "e27", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020078", "target": "http://purl.obolibrary.org/obo/TO_0000301", "id": "e28", "size": 100}, {"source": "http://purl.obolibrary.org/obo/TO_0020118", "target": "http://purl.obolibrary.org/obo/TO_0000301", "id":  ...
