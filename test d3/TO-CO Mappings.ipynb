# %%
# import libraries (including our short d3_lib script)
from IPython.core.display import HTML
import d3_lib, random
import re
import json

# %% [markdown]
# ### TO hierarchy

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# #CONSTRUCT
# #{
# #    ?x rdfs:subClassOf ?o .
# #}
# SELECT ?x ?xlabel ?o ?olabel
# WHERE
# {
#     ?x rdfs:subClassOf ?o .
#     filter(!isblank(?o))
#     filter(!regex(str(?o), "PATO"))
#     filter(regex(str(?o), "TO"))
#     ?x rdfs:label ?xlabel .
#     ?o rdfs:label ?olabel .
# }' > to.json

# %% [markdown]
# ### create the JSON file from TO

# %%
with open('to.json') as data_file:    
    data = json.load(data_file)
    
    list = data["results"]["bindings"]
    
    graph = {"nodes": [], "links": []}
    #force plant trait to be he first node
    graph["nodes"].append( {"name": "plant trait", "value": 0.5, "group": 9, "id": "http://purl.obolibrary.org/obo/TO_0000387" } )
    for entry in list:
        x = 1
        o = 1
        #check if the nodes already exist in the graph
        for e in graph["nodes"]:
            if e["name"] == entry["xlabel"]["value"]:
                x=graph["nodes"].index(e)
            if e["name"] == entry["olabel"]["value"]:
                o=graph["nodes"].index(e)
        # if the term does not exist, create it        
        if x==1:
            graph["nodes"].append( {"name": entry["xlabel"]["value"], "value": 0.5, "group": 9, "id":entry["x"]["value"] } )
            x=len(graph["nodes"])-1
        if o==1:
            graph["nodes"].append( {"name": entry["olabel"]["value"], "value": 0.5, "group": 9, "id":entry["o"]["value"]} )
            o=len(graph["nodes"])-1
            
        # create the link
        if  entry["x"]["value"] != entry["o"]["value"]:
            graph["links"].append( {"source": x, "target": o, "value": 5} )

# %% [markdown]
# ### add CO mappings

# %%
with open('co.json') as data_file:    
    co = json.load(data_file)
    
    #create the nodes
    for entry in co:
        if "CO_341" in entry["id"]:
            entry["group"] = 1
        if "CO_336" in entry["id"]:
            entry["group"] = 2
        if "CO_322" in entry["id"]:
            entry["group"] = 3
        if "CO_321" in entry["id"]:
            entry["group"] = 4
        if "CO_331" in entry["id"]:
            entry["group"] = 5
        if "CO_339" in entry["id"]:
            entry["group"] = 6
        if "CO_334" in entry["id"]:
            entry["group"] = 7
        if "CO_320" in entry["id"]:
            entry["group"] = 8
            
        entry["value"] = 1
        graph["nodes"].append(entry)

# %%
with open('COTOMappings.json') as data_file:    
    coto = json.load(data_file)
    
    #create the links
    for entry in coto:
        #get the indexes of existing nodes
        for e in graph["nodes"]:
            if e["id"] == entry["x"]:
                x=graph["nodes"].index(e)
            if e["id"] == entry["o"]:
                o=graph["nodes"].index(e)
                #update the size of the TO class
                e["value"]=e["value"]+0.1
        
        graph["links"].append( {"source": x, "target": o, "value": 5, "type": entry["type"]} )

# %%
# visualize as force-directed graph in D3
HTML(d3_lib.set_styles(['force_directed_graph']) + 
'<script src="lib/d3/d3.min.js"></script>' + 
      d3_lib.draw_graph('force_directed_graph', {'data': graph}) )
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
#
#
# /*.node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }*/
#
# .link {
#   stroke: #777;
#   stroke-opacity: 0.3;
#   stroke-width: 1.5px;
# }
#
# .node circle {
#   fill: #ccc;
#   stroke: #000;
#   stroke-width: 1.5px;
# }
#
# .node text {
#   display: none;
#   font: 10px sans-serif;
# }
#
# .node:hover circle {
#   fill: #000;
# }
#
# .node:hover text {
#   display: inline;
# }
#
# .cell {
#   fill: none;
#   pointer-events: all;
# }
#
# .nodetext { pointer-events: none; font: 10px sans-serif; }</style><script src="lib/d3/d3.min.js"></script>
#
#                 <div id='maindiv7790453446'></div>
#
#                 <script>
#
# // Based on http://bl.ocks.org/mbostock/4062045
#
# var width = 960,
#     height = 500;
#
# var color = d3.scale.category20();
#
# var force = d3.layout.force()
#     .charge(-300)
#     .linkDistance(50)
#     .size([width, height]);
#
# d3.select("#maindiv7790453446").selectAll("svg").remove();
#
# var svg = d3.select("#maindiv7790453446")
#   .append("svg")
#   .attr("width", 960)
#   .attr("height", 500)
#   .call(d3.behavior.zoom().on("zoom", function () {
#     svg.attr("transform", "translate(" + d3.event.translate + ")" + " scale(" + d3.event.scale + ")")
#   }))
#   .append("g");
#
#
# var graph = {'links': [{'source': 1, 'target': 2, 'value': 5}, {'source': 3, 'target': 2, 'value': 5}, {'source': 4, 'target': 2, 'value': 5}, {'source': 5, 'target': 2, 'value': 5}, {'source': 6, 'target': 2, 'value': 5}, {'source': 7, 'target': 2, 'value': 5}, {'source': 8, 'target': 9, 'value': 5}, {'source': 10, 'target': 11, 'value': 5}, {'source': 12, 'target': 13, 'value': 5}, {'source': 14, 'target': 13, 'value': 5}, {'source': 15, 'target': 13, 'value': 5}, {'source': 16, 'target': 13, 'value': 5}, {'source': 17, 'target': 18, 'value': 5}, {'source': 19, 'target': 18, 'value': 5}, {'source': 20, 'target': 21, 'value': 5}, {'source': 22, 'target': 21, 'value': 5}, {'source': 23, 'target': 21, 'value': 5}, {'source': 24, 'target': 21, 'value': 5}, {'source': 25, 'target': 26, 'value': 5}, {'source': 27, 'target': 28, 'value': 5}, {'source': 29, 'target': 28, 'value': 5}, {'source': 30, 'target': 28, 'value': 5}, {'source': 31, 'target': 28, 'value': 5}, {'source': 32, 'target': 33, 'value': 5}, {'source': 34, 'target': 35, 'value': 5}, {'source': 36, 'target': 35, 'value': 5}, {'source': 37, 'target': 35, 'value': 5}, {'source': 38, 'target': 35, 'value': 5}, {'source': 39, 'target': 35, 'value': 5}, {'source': 40, 'target': 41, 'value': 5}, {'source': 42, 'target': 43, 'value': 5}, {'source': 44, 'target': 43, 'value': 5}, {'source': 45, 'target': 43, 'value': 5}, {'source': 46, 'target': 47, 'value': 5}, {'source': 48, 'target': 47, 'value': 5}, {'source': 49, 'target': 47, 'value': 5}, {'source': 50, 'target': 47, 'value': 5}, {'source': 51, 'target': 47, 'value': 5}, {'source': 52, 'target': 47, 'value': 5}, {'source': 53, 'target': 47, 'value': 5}, {'source': 54, 'target': 47, 'value': 5}, {'source': 55, 'target': 47, 'value': 5}, {'source': 56, 'target': 57, 'value': 5}, {'source': 58, 'target': 57, 'value': 5}, {'source': 59, 'target': 60, 'value': 5}, {'source': 61, 'target': 60, 'value': 5}, {'source': 62, 'target': 60, 'value': 5}, {'source': 63, 'target': 64, 'value': 5}, {'source': 65, 'target': 64, 'value': 5}, {'source': 66, 'target': 64, 'value': 5}, {'source': 67, 'target': 64, 'value': 5}, {'source': 68, 'target': 64, 'value': 5}, {'source': 69, 'target': 70, 'value': 5}, {'source': 71, 'target': 70, 'value': 5}, {'source': 72, 'target': 73, 'value': 5}, {'source': 74, 'target': 73, 'value': 5}, {'source': 75, 'target': 73, 'value': 5}, {'source': 76, 'target': 73, 'value': 5}, {'source': 77, 'target': 73, 'value': 5}, {'source': 78, 'target': 73, 'value': 5}, {'source': 79, 'target': 80, 'value': 5}, {'source': 81, 'target': 80, 'value': 5}, {'source': 82, 'target': 80, 'value': 5}, {'source': 83, 'target': 84, 'value': 5}, {'source': 85, 'target': 84, 'value': 5}, {'source': 86, 'target': 84, 'value': 5}, {'source': 87, 'target': 88, 'value': 5}, {'source': 89, 'target': 88, 'value': 5}, {'source': 90, 'target': 88, 'value': 5}, {'source': 91, 'target': 88, 'value': 5}, {'source': 92, 'target': 83, 'value': 5}, {'source': 93, 'target': 83, 'value': 5}, {'source': 94, 'target': 95, 'value': 5}, {'source': 96, 'target': 95, 'value': 5}, {'source': 97, 'target': 98, 'value': 5}, {'source': 99, 'target': 98, 'value': 5}, {'source': 100, 'target': 101, 'value': 5}, {'source': 102, 'target': 101, 'value': 5}, {'source': 103, 'target': 104, 'value': 5}, {'source': 105, 'target': 104, 'value': 5}, {'source': 106, 'target': 107, 'value': 5}, {'source': 108, 'target': 109, 'value': 5}, {'source': 110, 'target': 109, 'value': 5}, {'source': 111, 'target': 112, 'value': 5}, {'source': 113, 'target': 112, 'value': 5}, {'source': 114, 'target': 115, 'value': 5}, {'source': 116, 'target': 115, 'value': 5}, {'source': 117, 'target': 115, 'value': 5}, {'source': 118, 'target': 115, 'value': 5}, {'source': 119, 'target': 115, 'value': 5}, {'source': 120, 'target': 115, 'value': 5}, {'source': 121, 'target': 122, 'value': 5}, {'source': 123, 'target': 122, 'value': 5}, {'source': 124, 'target': 122, 'value': 5}, {'sourc ...

# %%
with open('data.json', 'w') as outfile:
    json.dump(graph, outfile)

# %%
graph["nodes"]
# Out:
# [{'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006045',
#   'name': 'phosphorus concentration',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006045',
#   'name': 'phosphorus content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002666',
#   'name': 'seed phosphorus content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002666',
#   'name': 'phosphorus content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000645',
#   'name': 'relative phosphorus concentration',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000626',
#   'name': 'relative phosphorus distribution between shoot and root',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020114',
#   'name': 'shoot phosphorus content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001025',
#   'name': 'leaf phosphorus content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006019',
#   'name': 'floral organ identity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006019',
#   'name': 'organ identity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000970',
#   'name': 'panicle density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000970',
#   'name': 'inflorescence density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000994',
#   'name': 'androecium morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000994',
#   'name': 'collective phyllome structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000275',
#   'name': 'perianth morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000950',
#   'name': 'corolla morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000979',
#   'name': 'involucre morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001014',
#   'name': 'leaf dry weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001014',
#   'name': 'leaf weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000891',
#   'name': 'leaf wet weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000142',
#   'name': 'secondary branching of inflorescence',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000142',
#   'name': 'inflorescence branching',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006035',
#   'name': 'tertiary branching of inflorescence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002751',
#   'name': 'inflorescence branch arrangement',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000052',
#   'name': 'primary branching of inflorescence',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020069',
#   'name': 'spike exsertion',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020069',
#   'name': 'inflorescence exsertion',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000111',
#   'name': 'genetically engineered male sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000111',
#   'name': 'male sterility type',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000389',
#   'name': 'nuclear mediated male sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000199',
#   'name': 'genic male sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000580',
#   'name': 'cytoplasmic male sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000307',
#   'name': 'hexose content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000307',
#   'name': 'monosaccharide content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020079',
#   'name': 'beta-cryptoxanthin content',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020079',
#   'name': 'xanthophyll content',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020119',
#   'name': 'violaxanthin content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002701',
#   'name': 'lutein content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020078',
#   'name': 'zeaxanthin content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020118',
#   'name': 'neoxanthin content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000375',
#   'name': 'brown rice ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000375',
#   'name': 'grain length to width ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020021',
#   'name': 'basal axillary tertiary branch number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020021',
#   'name': 'basal axillary branch number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020022',
#   'name': 'basal axillary secondary branch number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020023',
#   'name': 'basal axillary primary branch number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020033',
#   'name': 'glume length',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020033',
#   'name': 'glume morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020038',
#   'name': 'glume waxiness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001000',
#   'name': 'glume cover',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020034',
#   'name': 'glume width',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001001',
#   'name': 'glume persistence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000978',
#   'name': 'glume shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000221',
#   'name': 'glume color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000474',
#   'name': 'glume opening',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020036',
#   'name': 'glume pubescence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000594',
#   'name': '100-polished grain weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000594',
#   'name': 'polished grain weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000595',
#   'name': '1000-polished grain weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000544',
#   'name': 'mesocotyl length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000544',
#   'name': 'mesocotyl morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000773',
#   'name': 'embryo mesocotyl morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000772',
#   'name': 'seedling mesocotyl morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002759',
#   'name': 'grain number',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002759',
#   'name': 'grain yield trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000589',
#   'name': 'average grain weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000450',
#   'name': 'grain yield per panicle',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020002',
#   'name': 'grain weight to panicle weight ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000449',
#   'name': 'grain yield per plant',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000619',
#   'name': 'vivipary',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000619',
#   'name': 'abscisic acid sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000253',
#   'name': 'seed dormancy',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012004',
#   'name': 'quantum yield',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012004',
#   'name': 'fluorescence related trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020115',
#   'name': 'chlorophyll fluorescence quenching',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020116',
#   'name': 'photochemical quenching',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020117',
#   'name': 'non photochemical quenching',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012005',
#   'name': 'chlorophyll fluorescence induction kinetics',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012009',
#   'name': 'continuous fluorescence yield',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000288',
#   'name': 'alpha-amylase activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000288',
#   'name': 'amylase activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000338',
#   'name': 'beta-amylase activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000336',
#   'name': 'total amylase activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000193',
#   'name': 'embryo shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000193',
#   'name': 'plant embryo morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000189',
#   'name': 'embryoless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000195',
#   'name': 'shootless embryo',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000451',
#   'name': 'large vascular bundle number to spikelet number ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000451',
#   'name': 'vascular bundle number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000558',
#   'name': 'small vascular bundle number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000539',
#   'name': 'large vascular bundle number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000538',
#   'name': 'large vascular bundle number to leaf area ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000194',
#   'name': 'globular embryo',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000113',
#   'name': 'giant embryo',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000940',
#   'name': 'tassel branch zone length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000940',
#   'name': 'tassel inflorescence length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000939',
#   'name': 'tassel spike length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006002',
#   'name': 'proline content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006002',
#   'name': 'amino acid content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002674',
#   'name': 'tryptophan content',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000571',
#   'name': 'shoot fresh weight',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000571',
#   'name': 'shoot axis weight',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000552',
#   'name': 'shoot dry weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000616',
#   'name': 'leaf perimeter',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000616',
#   'name': 'leaf shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020084',
#   'name': 'spiral leaf',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000561',
#   'name': 'space to culm ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000561',
#   'name': 'plant volume',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000813',
#   'name': 'tassel branch number',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000813',
#   'name': 'tassel branch morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000812',
#   'name': 'tassel branch dry weight',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002612',
#   'name': 'vegetative homeotic development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002612',
#   'name': 'homeotic development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002613',
#   'name': 'reproductive homeotic development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000489',
#   'name': 'carbohydrate composition related trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000489',
#   'name': 'seed composition based quality trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000491',
#   'name': 'fat and essential oil composition related trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000228',
#   'name': 'moisture content related trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000611',
#   'name': 'malt-extract percentage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000087',
#   'name': 'aroma',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000490',
#   'name': 'seed protein composition trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000892',
#   'name': 'stem size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000892',
#   'name': 'stem morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000132',
#   'name': 'basal internode diameter',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000051',
#   'name': 'stem strength',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000879',
#   'name': 'stem hairiness',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020083',
#   'name': 'stem diameter',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000056',
#   'name': 'stem color',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000549',
#   'name': 'rhizome morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000560',
#   'name': 'space per culm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001035',
#   'name': 'stem width',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002639',
#   'name': 'shoot branching',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000893',
#   'name': 'stem shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000634',
#   'name': 'stem node number',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000952',
#   'name': 'stem weight',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000577',
#   'name': 'stem angle',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000576',
#   'name': 'stem length',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000404',
#   'name': 'nodal rooting',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000531',
#   'name': 'anther length',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000531',
#   'name': 'anther morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000187',
#   'name': 'anther color',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000214',
#   'name': 'anther shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012008',
#   'name': 'quantum yield at a given wavelength',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012007',
#   'name': 'quantum yield determined by the light curve',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000720',
#   'name': 'leaf midrib color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000720',
#   'name': 'leaf vein color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002716',
#   'name': 'leaf sheath auricle pubescence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002716',
#   'name': 'leaf sheath auricle morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000294',
#   'name': 'leaf sheath auricle color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000226',
#   'name': 'auricleless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000046',
#   'name': 'f2-generation sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000046',
#   'name': 'hybrid incompatibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000042',
#   'name': 'f1-hybrid incompatibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000647',
#   'name': 'relative acid phosphatase activity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000647',
#   'name': 'acid phosphatase activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000011',
#   'name': 'nitrogen sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000011',
#   'name': 'primary macronutrient sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000008',
#   'name': 'potassium sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000102',
#   'name': 'phosphorus sensitivity',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000722',
#   'name': 'sporocyte development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000722',
#   'name': 'cell growth and development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002755',
#   'name': 'cell organelle development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002687',
#   'name': 'cell elongation trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000728',
#   'name': 'cell cycle trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000084',
#   'name': 'root number',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000084',
#   'name': 'root system morphology trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000205',
#   'name': 'white-backed planthopper resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000205',
#   'name': 'sogatodes resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020030',
#   'name': 'leaf lamina pubescence density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020030',
#   'name': 'leaf lamina pubescence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020029',
#   'name': 'leaf lamina pubscence length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002602',
#   'name': 'pistil size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002602',
#   'name': 'pistil morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002659',
#   'name': 'pistil number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002610',
#   'name': 'pistil length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000745',
#   'name': 'subterranean shoot axis tuber appearance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000745',
#   'name': 'subterranean shoot axis tuber morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000744',
#   'name': 'subterranean shoot axis tuber size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000743',
#   'name': 'subterranean shoot axis tuber shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000746',
#   'name': 'subterranean shoot axis tuber mass',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000020',
#   'name': 'black streak dwarf virus resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000020',
#   'name': 'viral disease resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000213',
#   'name': 'rice grassy stunt 1 and 2 virus resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000088',
#   'name': 'rice yellow mottle virus resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000386',
#   'name': 'rice ragged stunt virus resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000147',
#   'name': 'rice hoja blanca disease resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020067',
#   'name': 'barley yellow dwarf virus disease resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000413',
#   'name': 'rice tungro virus resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000568',
#   'name': 'shoot axis morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000782',
#   'name': 'inflorescence axis morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000346',
#   'name': 'tiller number',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000740',
#   'name': 'branch morphology trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002756',
#   'name': 'shoot habit',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000921',
#   'name': 'infructescence axis morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000567',
#   'name': 'tiller angle',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000517',
#   'name': 'relative shoot elongation under submergence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000776',
#   'name': 'peduncle morphology trait',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002715',
#   'name': 'chloroplast development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002715',
#   'name': 'plastid development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000943',
#   'name': 'aleurone layer color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000943',
#   'name': 'aleurone layer appearance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000242',
#   'name': 'microbial damage resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000242',
#   'name': 'crop damage resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000063',
#   'name': 'mimic response',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000347',
#   'name': 'weed damage',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000054',
#   'name': 'animal damage resistance',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000112',
#   'name': 'disease resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000339',
#   'name': 'stem thickness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000200',
#   'name': 'brittle culm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000061',
#   'name': 'node shattering',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002731',
#   'name': 'grain size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020103',
#   'name': 'adventitious root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020103',
#   'name': 'root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000516',
#   'name': 'relative root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000508',
#   'name': 'penetrated root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001012',
#   'name': 'lateral root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000586',
#   'name': 'seminal root length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001016',
#   'name': 'relative chlorophyll content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001016',
#   'name': 'chlorophyll content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012003',
#   'name': 'chlorophyll content in an extract',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000298',
#   'name': 'chlorophyll ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000293',
#   'name': 'chlorophyll-a content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000295',
#   'name': 'chlorophyll-b content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0012002',
#   'name': 'leaf chlorophyll content',
#   'value': 0.6},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000617',
#   'name': 'colored grain percentage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000617',
#   'name': 'pericarp color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000989',
#   'name': 'epicormic shoot system morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000989',
#   'name': 'shoot-borne shoot system morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001010',
#   'name': 'senesced leaf number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001010',
#   'name': 'leaf number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000049',
#   'name': 'gametophytic incompatibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000049',
#   'name': 'self-incompatibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000047',
#   'name': 'sporophytic incompatibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000266',
#   'name': 'chalky endosperm',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000462',
#   'name': 'gelatinization temperature',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000062',
#   'name': 'phenol reaction',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000097',
#   'name': 'amylopectin content',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000696',
#   'name': 'starch content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000211',
#   'name': 'gel consistency',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002689',
#   'name': 'leaf sheath length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002689',
#   'name': 'leaf sheath morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002724',
#   'name': 'leaf sheath color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002721',
#   'name': 'leaf sheath width',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000642',
#   'name': 'leaf sheath diameter',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000169',
#   'name': 'chinsurah boro CMS',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000169',
#   'name': 'aborted tri-nucleate stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000021',
#   'name': 'plant ovary morphology',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000021',
#   'name': 'plant structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000844',
#   'name': 'in vitro plant structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002683',
#   'name': 'plant cell morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000836',
#   'name': 'multi-tissue plant structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#   'name': 'trichome morphology trait',
#   'value': 0.6},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000843',
#   'name': 'portion of plant tissue morphology trait',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000398',
#   'name': 'whole plant morphology trait',
#   'value': 0.6},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000837',
#   'name': 'cardinal part of a multi-tissue plant structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000840',
#   'name': 'collective plant structure morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006009',
#   'name': 'lodicule morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006009',
#   'name': 'plant organ morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000747',
#   'name': 'phyllome morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000753',
#   'name': 'coleoptile morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000862',
#   'name': 'floral organ morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000738',
#   'name': 'plant axis morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006018',
#   'name': 'plant organ growth and development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000656',
#   'name': 'root development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000655',
#   'name': 'leaf growth and development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020094',
#   'name': 'nitrate content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020094',
#   'name': 'nitrogen content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000689',
#   'name': 'grain tenderness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000689',
#   'name': 'fruit tenderness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002645',
#   'name': 'malt tenderness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000726',
#   'name': 'microsporocyte number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000726',
#   'name': 'microsporocyte development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000505',
#   'name': 'leaf morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006014',
#   'name': 'phyllotaxy',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000446',
#   'name': 'leaf drying',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000826',
#   'name': 'leaf volume',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000828',
#   'name': 'leaf cover',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000419',
#   'name': 'vascular leaf morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000541',
#   'name': 'leaf position',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002637',
#   'name': 'leaf size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000824',
#   'name': 'leaf attitude',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000085',
#   'name': 'leaf rolling',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000709',
#   'name': 'leaf gloss',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000825',
#   'name': 'leaf flexibility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000652',
#   'name': 'leaf necrosis',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002722',
#   'name': 'leaf pubescence',
#   'value': 0.5},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000540',
#   'name': 'leaf area trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000925',
#   'name': 'non-vascular leaf morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000493',
#   'name': 'leaf composition trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000721',
#   'name': 'leaf adherence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000504',
#   'name': 'leaf temperature',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000326',
#   'name': 'leaf color',
#   'value': 0.6},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000124',
#   'name': 'flag leaf angle',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000124',
#   'name': 'flag leaf morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002757',
#   'name': 'flag leaf length',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000019',
#   'name': 'disk flower color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000019',
#   'name': 'flower color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020100',
#   'name': 'nitrate uptake',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020100',
#   'name': 'mineral and ion transport trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020101',
#   'name': 'starch mobilization',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020099',
#   'name': 'nitrate transport',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000511',
#   'name': 'phosphorus uptake',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000527',
#   'name': 'sodium uptake',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000514',
#   'name': 'potassium uptake',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006012',
#   'name': 'carpel morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006012',
#   'name': 'megasporophyll morphology trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000623',
#   'name': 'involucre bristle length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000623',
#   'name': 'inflorescence bristle length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006011',
#   'name': 'lodicule shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000857',
#   'name': 'lodicule type',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006010',
#   'name': 'lodicule number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000856',
#   'name': 'lodicule length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000026',
#   'name': 'pollen abortion type',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000245',
#   'name': 'pollen free',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000415',
#   'name': 'aborted bi-nucleate stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000060',
#   'name': 'aborted uni-nucleate stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000353',
#   'name': 'aborted at pollen maturity stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020098',
#   'name': 'nitrate sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000710',
#   'name': 'globulin protein content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000710',
#   'name': 'soluble protein content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000610',
#   'name': 'soluble to total protein ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002680',
#   'name': 'albumin content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002695',
#   'name': 'beta-carotene content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002695',
#   'name': 'cyclic carotene content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002696',
#   'name': 'alpha carotene content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000630',
#   'name': 'pedicel length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000630',
#   'name': 'inflorescence branch morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000954',
#   'name': 'spikelet rachilla morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0011004',
#   'name': 'inflorescence branch color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000846',
#   'name': 'inflorescence primary branch morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000765',
#   'name': 'petiole morphology trait',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000765',
#   'name': 'stalk morphology trait',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000884',
#   'name': 'petiolule morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000714',
#   'name': 'seminal rootless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000714',
#   'name': 'rootless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000234',
#   'name': 'radicleless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000230',
#   'name': 'crown rootless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000287',
#   'name': 'brown rice shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000287',
#   'name': 'grain shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000932',
#   'name': 'mannose content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000300',
#   'name': 'glucose content',
#   'value': 0.5},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000573',
#   'name': 'sepal color',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000573',
#   'name': 'sepal morphology trait',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002608',
#   'name': 'sepal width',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006040',
#   'name': 'sepal number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002607',
#   'name': 'sepal length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002604',
#   'name': 'sepal size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000569',
#   'name': 'white-backed planthopper egg mortality',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000127',
#   'name': 'rice grassy stunt virus-1 resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000126',
#   'name': 'rice grassy stunt virus-2 resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000367',
#   'name': 'basal leaf sheath color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000434',
#   'name': 'root activity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000434',
#   'name': 'vigor related trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000355',
#   'name': 'heterosis',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000425',
#   'name': 'anther culturability',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000430',
#   'name': 'germination rate',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000428',
#   'name': 'callus induction',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000296',
#   'name': 'vegetative vigor',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000515',
#   'name': 'relative growth rate',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0010001',
#   'name': 'percent germination',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000202',
#   'name': 'germination ratio',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000243',
#   'name': 'in vitro regeneration ability',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000096',
#   'name': 'ratooning ability',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000123',
#   'name': 'percent root mass density 15-30',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000123',
#   'name': 'percent root mass density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000125',
#   'name': 'percent root mass density 30-45',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000122',
#   'name': 'percent root mass density 0-15',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000320',
#   'name': 'rubisco to chlorophyll ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000110',
#   'name': 'wild abortive CMS',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000110',
#   'name': 'rice cytoplasmic male sterility',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000350',
#   'name': 'cms-hl type',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002732',
#   'name': 'flag leaf angle: early stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002733',
#   'name': 'flag leaf angle: late stage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000168',
#   'name': 'abiotic stress trait',
#   'value': 0.7999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000168',
#   'name': 'stress trait',
#   'value': 0.7999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000179',
#   'name': 'biotic stress trait',
#   'value': 0.5},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002741',
#   'name': 'grain surface area',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002741',
#   'name': 'fruit surface area',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002764',
#   'name': 'surface area of grain with hull',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000225',
#   'name': 'stamen number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020011',
#   'name': 'chickpea botrytis grey mold resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020011',
#   'name': 'fungal blight disease resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000663',
#   'name': 'wheat fusarium head blight resistance',
#   'value': 0.8999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020013',
#   'name': 'chickpea colleotrichum blight resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000662',
#   'name': 'barley fusarium head blight resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000691',
#   'name': 'Zea mays northern leaf blight disease resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020014',
#   'name': 'chickpea ascochyta blight resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000255',
#   'name': 'sheath blight disease resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000673',
#   'name': 'tetraploid wheat fusarium head blight resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020012',
#   'name': 'chickpea fusarium wild resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020015',
#   'name': 'sorghum leaf blight resistance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006049',
#   'name': 'iron concentration',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006049',
#   'name': 'iron content',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000488',
#   'name': 'seed quality trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000718',
#   'name': 'wrinkled seed',
#   'value': 0.1},
#  {'group': 9,
# ...
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000073',
#   'name': 'manganese sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000248',
#   'name': 'macronutrient sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000251',
#   'name': 'secondary macronutrient sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006024',
#   'name': 'ectopic lodicule development',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006024',
#   'name': 'lodicule development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006020',
#   'name': 'shoot apical meristem development',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006020',
#   'name': 'shoot meristem development',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000383',
#   'name': 'grain belly percent white',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000098',
#   'name': 'glutinous endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000390',
#   'name': 'grain core percent white',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000713',
#   'name': 'brittle endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000717',
#   'name': 'rough endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000665',
#   'name': 'grain core area white',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000716',
#   'name': 'etched endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000100',
#   'name': 'shrunken endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000104',
#   'name': 'floury endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000105',
#   'name': 'dull endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000231',
#   'name': 'endospermless',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000099',
#   'name': 'sugary endosperm',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000411',
#   'name': 'seed length to width ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000886',
#   'name': 'petiolule shape',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000887',
#   'name': 'petiolule length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000885',
#   'name': 'petiolule color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000498',
#   'name': 'female fertility restoration trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000308',
#   'name': 'male fertility restoration trait',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000019',
#   'name': 'seedling height',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000019',
#   'name': 'plant height',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001034',
#   'name': 'relative plant height',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001003',
#   'name': 'plant height uniformity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000464',
#   'name': 'albino plantlet differentiation frequency',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000933',
#   'name': 'plant phenological trait',
#   'value': 1.4000000000000001},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002712',
#   'name': 'stay green trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000949',
#   'name': 'seedling growth and development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000783',
#   'name': 'inflorescence axis size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002754',
#   'name': 'inflorescence axis texture',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000270',
#   'name': 'inflorescence axis angle',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0011003',
#   'name': 'inflorescence axis color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000134',
#   'name': 'alkali digestion',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000290',
#   'name': 'flavonoid content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000675',
#   'name': 'ferulic acid content',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002758',
#   'name': 'flag leaf lamina width',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0011006',
#   'name': 'penultimate leaf lamina width',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000155',
#   'name': 'drought susceptibility index',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000155',
#   'name': 'drought sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000695',
#   'name': 'leaf margin color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000695',
#   'name': 'leaf margin morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000830',
#   'name': 'leaf lamina margin morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006063',
#   'name': 'leaf margin serrated',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000599',
#   'name': 'enzyme activity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000465',
#   'name': 'mineral and ion content related trait',
#   'value': 0.5},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000217',
#   'name': 'genic male sterility-thermo-photoperiod sensitive',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000067',
#   'name': 'genic male sterility-thermo sensitive',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000009',
#   'name': 'genic male sterility-photoperiod sensitive',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000908',
#   'name': 'fruit hollowness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002634',
#   'name': 'fruit firmness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000694',
#   'name': 'fruit crispness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000686',
#   'name': 'juiciness',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002622',
#   'name': 'locular tissue trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000613',
#   'name': 'groat percentage',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002729',
#   'name': 'fruit senescing quality trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002694',
#   'name': 'fruit flavor trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002708',
#   'name': 'xylem color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002708',
#   'name': 'vascular tissue morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002709',
#   'name': 'phloem color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000002',
#   'name': 'secondary xylem volumetric density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006065',
#   'name': 'seedling hypocotyl length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000759',
#   'name': 'seedling hypocotyl color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000781',
#   'name': 'seedling hypocotyl size',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000638',
#   'name': 'spike width',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0001004',
#   'name': 'basal tiller number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000460',
#   'name': 'light intensity sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000460',
#   'name': 'light sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000229',
#   'name': 'photoperiod sensitivity trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000265',
#   'name': 'light quality sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006026',
#   'name': 'floral bract number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006026',
#   'name': 'floral bract development trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002768',
#   'name': 'spikelet length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000563',
#   'name': 'spikelet length to width ratio',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000501',
#   'name': 'spikelet weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000625',
#   'name': 'spikelet density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000564',
#   'name': 'spikelet width',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000180',
#   'name': 'spikelet fertility',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006034',
#   'name': 'tertiary branch number',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000259',
#   'name': 'heat tolerance',
#   'value': 0.7999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000303',
#   'name': 'cold tolerance',
#   'value': 0.8999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000734',
#   'name': 'grain length',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000734',
#   'name': 'fruit length',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002744',
#   'name': 'fruit curved length',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000918',
#   'name': 'trichome hirsute',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000914',
#   'name': 'trichome canescent',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000915',
#   'name': 'trichome capillary',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000916',
#   'name': 'trichome clavate',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000913',
#   'name': 'trichome acircular',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000912',
#   'name': 'trichome appressed',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000917',
#   'name': 'trichome ensiform',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000758',
#   'name': 'stem internode morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000000',
#   'name': 'stem internode bent',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000426',
#   'name': 'stem internode color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000468',
#   'name': 'leaf blast disease resistance',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000477',
#   'name': 'panicle blast disease resistance',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000009',
#   'name': 'branch angle',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000008',
#   'name': 'branch position',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000018',
#   'name': 'stem epidermis color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000017',
#   'name': 'stem cortex color',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000575',
#   'name': 'endosperm morphology trait',
#   'value': 0.30000000000000004},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000942',
#   'name': 'aleurone layer morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000946',
#   'name': 'endocarp morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000838',
#   'name': 'seed coat morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0002663',
#   'name': 'leaf necrosis tolerance',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000702',
#   'name': 'starch concentration',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000372',
#   'name': 'amylose to amylopectin ratio',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000328',
#   'name': 'sucrose content',
#   'value': 0.6},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000196',
#   'name': 'amylose content',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000015',
#   'name': 'oxygen sensitivity',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_1000004',
#   'name': 'infructescence position',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000455',
#   'name': 'seed set percent',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000583',
#   'name': 'infructescence weight',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000894',
#   'name': 'fruit number trait',
#   'value': 0.7999999999999999},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000976',
#   'name': 'ear infructescence morphology trait',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000814',
#   'name': 'tassel inflorescence type',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000799',
#   'name': 'tassel inflorescence diameter',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000796',
#   'name': 'tassel inflorescence circumference',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000795',
#   'name': 'tassel inflorescence color',
#   'value': 0.4},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000797',
#   'name': 'tassel inflorescence height',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006066',
#   'name': 'leaf trichome density',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0006041',
#   'name': 'tepal number',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000574',
#   'name': 'tepal color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000819',
#   'name': 'inflorescence bract color',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0020120',
#   'name': 'involucral bract spine presence',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000818',
#   'name': 'inflorescence bract cover',
#   'value': 0.1},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000817',
#   'name': 'inflorescence bract length',
#   'value': 0.2},
#  {'group': 9,
#   'id': 'http://purl.obolibrary.org/obo/TO_0000951',
#   'name': 'corolla color',
#   'value': 0.1},
#  ...]
