# %% [markdown]
# Build a graph from TO using D3

# %%
# import libraries (including our short d3_lib script)
from IPython.core.display import HTML
import d3_lib, random
import re

# %% [markdown]
# ### get all the TO classes and the sublcassOf relations

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# #CONSTRUCT
# #{
# #    ?x rdfs:subClassOf ?o .
# #}
# SELECT ?x ?xlabel ?o ?olabel
# WHERE
# {
#     ?x rdfs:subClassOf ?o .
#     filter(!isblank(?o))
#     filter(!regex(str(?o), "PATO"))
#     filter(regex(str(?o), "TO"))
#     ?x rdfs:label ?xlabel .
#     ?o rdfs:label ?olabel .
# }' > to.json

# %% [markdown]
# ### get for each TO class its level in the hierarchy
#
# will be used to customise the graph

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# select ?super (count(?mid) as ?distance) {
#   ?super rdfs:subClassOf* ?mid .
#   ?mid rdfs:subClassOf+ <http://purl.obolibrary.org/obo/TO_0000387> .
# }
# group by ?super ?sub
# order by ?super ?sub' > level.json

# %% [markdown]
# ### get for each TO class its type

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# select ?sub ?mid {
#   ?sub rdfs:subClassOf* ?mid .
#   ?mid rdfs:subClassOf <http://purl.obolibrary.org/obo/TO_0000387> .
# }
# group by ?mid ?sub
# ' > type.json

# %% [markdown]
# ### create the JSON file used by d3js

# %%
import json

with open('to.json') as data_file:    
    data = json.load(data_file)
    
with open('level.json') as level_file:    
    level = json.load(level_file)
    
with open('type.json') as type_file:    
    type = json.load(type_file) 
    
    list = data["results"]["bindings"]
    
    graph = {"nodes": [], "links": []}
    
    for entry in list:
        x = 1
        o = 1
        #check if the nodes already exist in the graph
        for e in graph["nodes"]:
            if e["name"] == entry["xlabel"]["value"]:
                x=graph["nodes"].index(e)
            if e["name"] == entry["olabel"]["value"]:
                o=graph["nodes"].index(e)
        # if the term does not exist, create it        
        if x==1:
            for l in level["results"]["bindings"]:
                if l["super"]["value"] == entry["x"]["value"]:
                    graph["nodes"].append( {"name": entry["xlabel"]["value"], "value": 1/int(l["distance"]["value"]), "id":entry["x"]["value"] } )
                    x=len(graph["nodes"])-1
        if o==1:
            for l in level["results"]["bindings"]:
                if l["super"]["value"] == entry["o"]["value"]:
                    graph["nodes"].append( {"name": entry["olabel"]["value"], "value": 1/int(l["distance"]["value"]), "id":entry["x"]["value"]} )
                    o=len(graph["nodes"])-1

        # create the link
        if  entry["x"]["value"] != entry["o"]["value"]:
            graph["links"].append( {"source": x, "target": o, "value": 10} )
    
    # add the types
    for node in graph["nodes"]:
        for t in type["results"]["bindings"]:
            if t["sub"]["value"] == node["id"]:
                node["group"] = re.findall('\d+', t["mid"]["value"])
        #"group": re.findall('\d+', t["mid"]["value"] ),
        
#data["results"]['bindings'][0]['x']['value']

# %%
# visualize as force-directed graph in D3
HTML(d3_lib.set_styles(['force_directed_graph']) + 
'<script src="lib/d3/d3.min.js"></script>' + 
      d3_lib.draw_graph('force_directed_graph', {'data': graph}) )
# Out:
# <style>
# /* http://bl.ocks.org/mbostock/4062045 */
#
#
# /*.node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }*/
#
# .link {
#   stroke: #777;
#   stroke-opacity: 0.3;
#   stroke-width: 1.5px;
# }
#
# .node circle {
#   fill: #ccc;
#   stroke: #000;
#   stroke-width: 1.5px;
# }
#
# .node text {
#   display: none;
#   font: 10px sans-serif;
# }
#
# .node:hover circle {
#   fill: #000;
# }
#
# .node:hover text {
#   display: inline;
# }
#
# .cell {
#   fill: none;
#   pointer-events: all;
# }
#
# .nodetext { pointer-events: none; font: 10px sans-serif; }</style><script src="lib/d3/d3.min.js"></script>
#
#                 <div id='maindiv2370253972'></div>
#
#                 <script>
#
# // Based on http://bl.ocks.org/mbostock/4062045
#
# var width = 960,
#     height = 500;
#
# var color = d3.scale.category20();
#
# var force = d3.layout.force()
#     .charge(-300)
#     .linkDistance(50)
#     .size([width, height]);
#
# d3.select("#maindiv2370253972").selectAll("svg").remove();
# // var svg = d3.select("#maindiv2370253972").append("svg")
# //     .attr("width", width)
# //     .attr("height", height)
# //     ;
#
#
#
# var svg = d3.select("#maindiv2370253972")
#   .append("svg")
#   .attr("width", 960)
#   .attr("height", 500)
#   .call(d3.behavior.zoom().on("zoom", function () {
#     svg.attr("transform", "translate(" + d3.event.translate + ")" + " scale(" + d3.event.scale + ")")
#   }))
#   .append("g");
#
#
# var graph = {'nodes': [{'value': 0.25, 'group': ['0000277'], 'name': 'phosphorus concentration', 'id': 'http://purl.obolibrary.org/obo/TO_0006045'}, {'value': 0.3333333333333333, 'group': ['0000277'], 'name': 'phosphorus content', 'id': 'http://purl.obolibrary.org/obo/TO_0006045'}, {'value': 0.25, 'group': ['0000277'], 'name': 'seed phosphorus content', 'id': 'http://purl.obolibrary.org/obo/TO_0002666'}, {'value': 0.3333333333333333, 'group': ['0000277'], 'name': 'phosphorus content', 'id': 'http://purl.obolibrary.org/obo/TO_0002666'}, {'value': 0.08333333333333333, 'group': ['0000164'], 'name': 'relative phosphorus concentration', 'id': 'http://purl.obolibrary.org/obo/TO_0000645'}, {'value': 0.08333333333333333, 'group': ['0000164'], 'name': 'relative phosphorus distribution between shoot and root', 'id': 'http://purl.obolibrary.org/obo/TO_0000626'}, {'value': 0.25, 'group': ['0000277'], 'name': 'shoot phosphorus content', 'id': 'http://purl.obolibrary.org/obo/TO_0020114'}, {'value': 0.25, 'group': ['0000277'], 'name': 'leaf phosphorus content', 'id': 'http://purl.obolibrary.org/obo/TO_0001025'}, {'value': 0.16666666666666666, 'group': ['0000357'], 'name': 'floral organ identity', 'id': 'http://purl.obolibrary.org/obo/TO_0006019'}, {'value': 0.2, 'group': ['0000357'], 'name': 'organ identity', 'id': 'http://purl.obolibrary.org/obo/TO_0006019'}, {'value': 0.1, 'group': ['0000017'], 'name': 'panicle density', 'id': 'http://purl.obolibrary.org/obo/TO_0000970'}, {'value': 0.125, 'group': ['0000017'], 'name': 'inflorescence density', 'id': 'http://purl.obolibrary.org/obo/TO_0000970'}, {'value': 0.16666666666666666, 'group': ['0000017'], 'name': 'androecium morphology trait', 'id': 'http://purl.obolibrary.org/obo/TO_0000994'}, {'value': 0.2, 'group': ['0000017'], 'name': 'collective phyllome structure morphology trait', 'id': 'http://purl.obolibrary.org/obo/TO_0000994'}, {'value': 0.16666666666666666, 'group': ['0000017'], 'name': 'perianth morphology trait', 'id': 'http://purl.obolibrary.org/obo/TO_0000275'}, {'value': 0.16666666666666666, 'group': ['0000017'], 'name': 'corolla morphology trait', 'id': 'http://purl.obolibrary.org/obo/TO_0000950'}, {'value': 0.16666666666666666, 'group': ['0000017'], 'name': 'involucre morphology trait', 'id': 'http://purl.obolibrary.org/obo/TO_0000979'}, {'value': 0.125, 'group': ['0000017'], 'name': 'leaf dry weight', 'id': 'http://purl.obolibrary.org/obo/TO_0001014'}, {'value': 0.14285714285714285, 'group': ['0000017'], 'name': 'leaf weight', 'id': 'http://purl.obolibrary.org/obo/TO_0001014'}, {'value': 0.125, 'group': ['0000017'], 'name': 'leaf wet weight', 'id': 'http://purl.obolibrary.org/obo/TO_0000891'}, {'value': 0.07692307692307693, 'group': ['0000357'], 'name': 'secondary branching of inflorescence', 'id': 'http://purl.obolibrary.org/obo/TO_0000142'}, {'value': 0.08333333333333333, 'group': ['0000357'], 'name': 'inflorescence branching', 'id': 'http://purl.obolibrary.org/obo/TO_0000142'}, {'value': 0.07692307692307693, 'group': ['0000017'], 'name': 'tertiary branching of inflorescence', 'id': 'http://purl.obolibrary.org/obo/TO_0006035'}, {'value': 0.07692307692307693, 'group': ['0000017'], 'name': 'inflorescence branch arrangement', 'id': 'http://purl.obolibrary.org/obo/TO_0002751'}, {'value': 0.07692307692307693, 'group': ['0000017'], 'name': 'primary branching of inflorescence', 'id': 'http://purl.obolibrary.org/obo/TO_0000052'}, {'value': 0.1111111111111111, 'group': ['0000017'], 'name': 'spike exsertion', 'id': 'http://purl.obolibrary.org/obo/TO_0020069'}, {'value': 0.125, 'group': ['0000017'], 'name': 'inflorescence exsertion', 'id': 'http://purl.obolibrary.org/obo/TO_0020069'}, {'value': 0.2, 'group': ['0000392'], 'name': 'genetically engineered male sterility', 'id': 'http://purl.obolibrary.org/obo/TO_0000111'}, {'value': 0.25, 'group': ['0000392'], 'name': 'male sterility type', 'id': 'http://purl.obolibrary.org/obo/TO_0000111'}, {'value': 0.2, 'group': ['0000392'], 'name': 'nucl ...

# %% [markdown]
# ### Extras
# #### Save the graph

# %%
with open('data.json', 'w') as outfile:
    json.dump(graph, outfile)
